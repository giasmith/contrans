# %% [markdown]
# ## Connecting to Mongo DB

# %%
import numpy as np
import pandas as pd
import pymongo
import os
from bson.json_util import loads, dumps

# %%
propublica_token = os.environ['propub_token']
mongo_username = os.environ['MONGO_INITDB_ROOT_USERNAME']
mongo_password = os.environ['MONGO_INITDB_ROOT_PASSWORD']
mongo_init_db = os.environ['MONGO_INITDB_DATABASE']
email = 'nqj5zk@virginia.edu'

# %%
myclient = pymongo.MongoClient(f"mongodb://{mongo_username}:{mongo_password}@mongo:27017/{mongo_init_db}?authSource=admin")

# %%
contrans_db = myclient['contrans']

# %%
bills = contrans_db['bills']

# %% [markdown]
# ## Count Documents

# %%
bills.count_documents({})
# Curly braces are JSON queries
# Out:
# 17071

# %% [markdown]
# ## Filter Rows

# %%
myquery = bills.find({'sponsor_state': 'VA',
                      'bill_type': 'hr'})
L= loads(dumps(myquery))

# %%
L
# Out:
# [{'_id': ObjectId('63764dc6e6cbfc0792a0cd48'),
#   'bill_id': 'hr9304-117',
#   'bill_slug': 'hr9304',
#   'bill_type': 'hr',
#   'number': 'H.R.9304',
#   'bill_uri': 'https://api.propublica.org/congress/v1/117/bills/hr9304.json',
#   'title': 'To amend the Immigration and Nationality Act to provide access to counsel for children and other vulnerable populations, and for other purposes.',
#   'short_title': 'To amend the Immigration and Nationality Act to provide access to counsel for children and other vulnerable populations, and for other purposes.',
#   'sponsor_title': 'Rep.',
#   'sponsor_id': 'M001200',
#   'sponsor_name': 'A. Donald McEachin',
#   'sponsor_state': 'VA',
#   'sponsor_party': 'D',
#   'sponsor_uri': 'https://api.propublica.org/congress/v1/members/M001200.json',
#   'gpo_pdf_uri': None,
#   'congressdotgov_url': 'https://www.congress.gov/bill/117th-congress/house-bill/9304',
#   'govtrack_url': 'https://www.govtrack.us/congress/bills/117/hr9304',
#   'introduced_date': '2022-11-15',
#   'active': False,
#   'last_vote': None,
#   'house_passage': None,
#   'senate_passage': None,
#   'enacted': None,
#   'vetoed': None,
#   'cosponsors': 9,
#   'cosponsors_by_party': {'D': 9},
#   'committees': 'House Judiciary Committee',
#   'committee_codes': ['HSJU'],
#   'subcommittee_codes': [],
#   'primary_subject': '',
#   'summary': '',
#   'summary_short': '',
#   'latest_major_action_date': '2022-11-15',
#   'latest_major_action': 'Referred to the House Committee on the Judiciary.'},
#  {'_id': ObjectId('63764dc7e6cbfc0792a0cdbc'),
#   'bill_id': 'hr9228-117',
#   'bill_slug': 'hr9228',
#   'bill_type': 'hr',
#   'number': 'H.R.9228',
#   'bill_uri': 'https://api.propublica.org/congress/v1/117/bills/hr9228.json',
#   'title': 'To amend the Public Health Service Act with respect to the information security policies and practices of the National Institutes of Health, and for other purposes.',
#   'short_title': 'Ensuring Cybersecurity at the NIH Act of 2022',
#   'sponsor_title': 'Rep.',
#   'sponsor_id': 'G000568',
#   'sponsor_name': 'Morgan Griffith',
#   'sponsor_state': 'VA',
#   'sponsor_party': 'R',
#   'sponsor_uri': 'https://api.propublica.org/congress/v1/members/G000568.json',
#   'gpo_pdf_uri': None,
#   'congressdotgov_url': 'https://www.congress.gov/bill/117th-congress/house-bill/9228',
#   'govtrack_url': 'https://www.govtrack.us/congress/bills/117/hr9228',
#   'introduced_date': '2022-10-25',
#   'active': False,
#   'last_vote': None,
#   'house_passage': None,
#   'senate_passage': None,
#   'enacted': None,
#   'vetoed': None,
#   'cosponsors': 0,
#   'cosponsors_by_party': {},
#   'committees': 'House Energy and Commerce Committee',
#   'committee_codes': ['HSIF'],
#   'subcommittee_codes': [],
#   'primary_subject': 'Health',
#   'summary': '',
#   'summary_short': '',
#   'latest_major_action_date': '2022-10-25',
#   'latest_major_action': 'Referred to the House Committee on Energy and Commerce.'},
#  {'_id': ObjectId('63764dc8e6cbfc0792a0ce2c'),
#   'bill_id': 'hr9153-117',
#   'bill_slug': 'hr9153',
#   'bill_type': 'hr',
#   'number': 'H.R.9153',
#   'bill_uri': 'https://api.propublica.org/congress/v1/117/bills/hr9153.json',
#   'title': 'To repeal the Federal Motor Carrier Safety Administration\'s rule titled "Minimum Training Requirements for Entry-Level Commercial Motor Vehicle Operators".',
#   'short_title': 'Trucking Workforce Improvement Act',
#   'sponsor_title': 'Rep.',
#   'sponsor_id': 'G000595',
#   'sponsor_name': 'Robert Good',
#   'sponsor_state': 'VA',
#   'sponsor_party': 'R',
#   'sponsor_uri': 'https://api.propublica.org/congress/v1/members/G000595.json',
#   'gpo_pdf_uri': None,
#   'congressdotgov_url': 'https://www.congress.gov/bill/117th-congress/house-bill/9153',
#   'govtrack_url': 'https://www.govtrack.us/congress/bills/117/hr9153',
#   'introduced_date': '2022-10-07',
#   'active': False,
#   'last_vote': None,
#   'house_passage': None,
#   'senate_passage': None,
#   'enacted': None,
#   'vetoed': None,
#   'cosponsors': 6,
#   'cosponsors_by_party': {'R': 6},
#   'committees': 'House Transportation and Infrastructure Committee',
#   'committee_codes': ['HSPW'],
#   'subcommittee_codes': ['HSPW12'],
#   'primary_subject': 'Transportation and Public Works',
#   'summary': '',
#   'summary_short': '',
#   'latest_major_action_date': '2022-10-11',
#   'latest_major_action': 'Referred to the Subcommittee on Highways and Transit.'},
#  {'_id': ObjectId('63764dc9e6cbfc0792a0ce60'),
#   'bill_id': 'hr9088-117',
#   'bill_slug': 'hr9088',
#   'bill_type': 'hr',
#   'number': 'H.R.9088',
#   'bill_uri': 'https://api.propublica.org/congress/v1/117/bills/hr9088.json',
#   'title': 'To prohibit the Secretary of the Interior and the Secretary of Agriculture from prohibiting the use of lead ammunition or tackle on certain Federal land or water under the jurisdiction of the Secretary of the Interior and the Secretary of Agriculture, and for other purposes.',
#   'short_title': 'Protecting Access for Hunters and Anglers Act of 2022',
#   'sponsor_title': 'Rep.',
#   'sponsor_id': 'W000804',
#   'sponsor_name': 'Robert J. Wittman',
#   'sponsor_state': 'VA',
#   'sponsor_party': 'R',
#   'sponsor_uri': 'https://api.propublica.org/congress/v1/members/W000804.json',
#   'gpo_pdf_uri': None,
#   'congressdotgov_url': 'https://www.congress.gov/bill/117th-congress/house-bill/9088',
#   'govtrack_url': 'https://www.govtrack.us/congress/bills/117/hr9088',
#   'introduced_date': '2022-09-30',
#   'active': False,
#   'last_vote': None,
#   'house_passage': None,
#   'senate_passage': None,
#   'enacted': None,
#   'vetoed': None,
#   'cosponsors': 47,
#   'cosponsors_by_party': {'R': 47},
#   'committees': 'House Agriculture Committee',
#   'committee_codes': ['HSII'],
#   'subcommittee_codes': ['HSAG15'],
#   'primary_subject': 'Public Lands and Natural Resources',
#   'summary': '',
#   'summary_short': '',
#   'latest_major_action_date': '2022-10-28',
#   'latest_major_action': 'Referred to the Subcommittee on Conservation and Forestry.'},
#  {'_id': ObjectId('63764dc9e6cbfc0792a0ce73'),
#   'bill_id': 'hr9106-117',
#   'bill_slug': 'hr9106',
#   'bill_type': 'hr',
#   'number': 'H.R.9106',
#   'bill_uri': 'https://api.propublica.org/congress/v1/117/bills/hr9106.json',
#   'title': 'To provide for drinking water well replacement for Chincoteague, Virginia, and for other purposes.',
#   'short_title': 'Chincoteague Water Well Replacement Act',
#   'sponsor_title': 'Rep.',
#   'sponsor_id': 'L000591',
#   'sponsor_name': 'Elaine Luria',
#   'sponsor_state': 'VA',
#   'sponsor_party': 'D',
#   'sponsor_uri': 'https://api.propublica.org/congress/v1/members/L000591.json',
#   'gpo_pdf_uri': None,
#   'congressdotgov_url': 'https://www.congress.gov/bill/117th-congress/house-bill/9106',
#   'govtrack_url': 'https://www.govtrack.us/congress/bills/117/hr9106',
#   'introduced_date': '2022-09-30',
#   'active': False,
#   'last_vote': None,
#   'house_passage': None,
#   'senate_passage': None,
#   'enacted': None,
#   'vetoed': None,
#   'cosponsors': 0,
#   'cosponsors_by_party': {},
#   'committees': 'House Science, Space, and Technology Committee',
#   'committee_codes': ['HSSY'],
#   'subcommittee_codes': [],
#   'primary_subject': 'Environmental Protection',
#   'summary': '',
#   'summary_short': '',
#   'latest_major_action_date': '2022-09-30',
#   'latest_major_action': 'Referred to the House Committee on Science, Space, and Technology.'},
#  {'_id': ObjectId('63764dc9e6cbfc0792a0ce84'),
#   'bill_id': 'hr9036-117',
#   'bill_slug': 'hr9036',
#   'bill_type': 'hr',
#   'number': 'H.R.9036',
#   'bill_uri': 'https://api.propublica.org/congress/v1/117/bills/hr9036.json',
#   'title': 'To establish a grant program to facilitate peer-to-peer suicide prevention programs for middle school and high school students, and for other purposes.',
#   'short_title': 'Peer-to-Peer Suicide Prevention Act',
#   'sponsor_title': 'Rep.',
#   'sponsor_id': 'B001292',
#   'sponsor_name': 'Donald Beyer',
#   'sponsor_state': 'VA',
#   'sponsor_party': 'D',
#   'sponsor_uri': 'https://api.propublica.org/congress/v1/members/B001292.json',
#   'gpo_pdf_uri': None,
#   'congressdotgov_url': 'https://www.congress.gov/bill/117th-congress/house-bill/9036',
#   'govtrack_url': 'https://www.govtrack.us/congress/bills/117/hr9036',
#   'introduced_date': '2022-09-29',
#   'active': False,
#   'last_vote': None,
#   'house_passage': None,
#   'senate_passage': None,
#   'enacted': None,
#   'vetoed': None,
#   'cosponsors': 0,
#   'cosponsors_by_party': {},
#   'committees': 'House Energy and Commerce Committee',
#   'committee_codes': ['HSED'],
#   'subcommittee_codes': [],
#   'primary_subject': 'Education',
#   'summary': 'Peer-to-Peer Suicide Prevention Act This bill directs the Department of Education to establish a program to award grants to eligible entities (e.g., local educational agencies) for facilitating peer-to-peer suicide prevention programs for middle and high school students.',
#   'summary_short': 'Peer-to-Peer Suicide Prevention Act This bill directs the Department of Education to establish a program to award grants to eligible entities (e.g., local educational agencies) for facilitating peer-to-peer suicide prevention programs for middle and high school students.',
#   'latest_major_action_date': '2022-09-29',
#   'latest_major_action': 'Referred to the Committee on Education and Labor, and in addition to the Committee on Energy and Commerce, for a period to be subsequently determined by the Speaker, in each case for consideration of such provisions as fall within the jurisdiction of the committee concerned.'},
#  {'_id': ObjectId('63764dcbe6cbfc0792a0cf5f'),
#   'bill_id': 'hr9011-117',
#   'bill_slug': 'hr9011',
#   'bill_type': 'hr',
#   'number': 'H.R.9011',
#   'bill_uri': 'https://api.propublica.org/congress/v1/117/bills/hr9011.json',
#   'title': 'To amend the Federal Food, Drug, and Cosmetic Act to direct the Secretary of Health and Human Services to establish a process to allow the holders of abbreviated new drug applications to make labeling changes to include new or updated safety-related information, and for other purposes.',
#   'short_title': 'Updated Drug Labeling for Patient Safety Act',
#   'sponsor_title': 'Rep.',
#   'sponsor_id': 'M001200',
#   'sponsor_name': 'A. Donald McEachin',
#   'sponsor_state': 'VA',
#   'sponsor_party': 'D',
#   'sponsor_uri': 'https://api.propublica.org/congress/v1/members/M001200.json',
#   'gpo_pdf_uri': None,
#   'congressdotgov_url': 'https://www.congress.gov/bill/117th-congress/house-bill/9011',
#   'govtrack_url': 'https://www.govtrack.us/congress/bills/117/hr9011',
#   'introduced_date': '2022-09-28',
#   'active': False,
#   'last_vote': None,
#   'house_passage': None,
#   'senate_passage': None,
#   'enacted': None,
#   'vetoed': None,
#   'cosponsors': 0,
#   'cosponsors_by_party': {},
#   'committees': 'House Energy and Commerce Committee',
#   'committee_codes': ['HSIF'],
#   'subcommittee_codes': [],
#   'primary_subject': 'Health',
#   'summary': '',
#   'summary_short': '',
#   'latest_major_action_date': '2022-09-28',
#   'latest_major_action': 'Referred to the House Committee on Energy and Commerce.'},
#  {'_id': ObjectId('63764dcbe6cbfc0792a0cf67'),
#   'bill_id': 'hr8992-117',
#   'bill_slug': 'hr8992',
#   'bill_type': 'hr',
#   'number': 'H.R.8992',
#   'bill_uri': 'https://api.propublica.org/congress/v1/117/bills/hr8992.json',
#   'title': 'To require a Federal methane super-emitter detection strategy, and for other purposes.',
#   'short_title': 'Methane Super-Emitter Strategy Act of 2022',
#   'sponsor_title': 'Rep.',
#   'sponsor_id': 'B001292',
#   'sponsor_name': 'Donald Beyer',
#   'sponsor_state': 'VA',
#   'sponsor_party': 'D',
#   'sponsor_uri': 'https://api.propublica.org/congress/v1/members/B001292.json',
#   'gpo_pdf_uri': None,
#   'congressdotgov_url': 'https://www.congress.gov/bill/117th-congress/house-bill/8992',
#   'govtrack_url': 'https://www.govtrack.us/congress/bills/117/hr8992',
#   'introduced_date': '2022-09-28',
#   'active': False,
#   'last_vote': None,
#   'house_passage': None,
#   'senate_passage': None,
#   'enacted': None,
#   'vetoed': None,
#   'cosponsors': 3,
#   'cosponsors_by_party': {'D': 3},
#   'committees': 'House Science, Space, and Technology Committee',
#   'committee_codes': ['HSSY'],
#   'subcommittee_codes': [],
#   'primary_subject': 'Environmental Protection',
#   'summary': 'Methane Super-Emitter Strategy Act of 2022 This bill requires the Environmental Protection Agency to enter an agreement with the National Academies of Sciences, Engineering, and Medicine to develop a science-based strategy to assess, evaluate, and make recommendations regarding the use of present and future greenhouse gas monitoring and detection capabilities.',
#   'summary_short': 'Methane Super-Emitter Strategy Act of 2022 This bill requires the Environmental Protection Agency to enter an agreement with the National Academies of Sciences, Engineering, and Medicine to develop a science-based strategy to assess, evaluate, and make recommendations regarding the use of present and future greenhouse gas monitoring and detection capabilities.',
#   'latest_major_action_date': '2022-09-28',
#   'latest_major_action': 'Referred to the House Committee on Science, Space, and Technology.'},
#  {'_id': ObjectId('63764dcce6cbfc0792a0cfd2'),
#   'bill_id': 'hr8956-117',
#   'bill_slug': 'hr8956',
#   'bill_type': 'hr',
#   'number': 'H.R.8956',
#   'bill_uri': 'https://api.propublica.org/congress/v1/117/bills/hr8956.json',
#   'title': 'To amend chapter 36 of title 44, United States Code, to improve the cybersecurity of the Federal Government, and for other purposes.',
#   'short_title': 'FedRAMP Authorization Act',
#   'sponsor_title': 'Rep.',
#   'sponsor_id': 'C001078',
#   'sponsor_name': 'Gerald E. Connolly',
#   'sponsor_state': 'VA',
#   'sponsor_party': 'D',
#   'sponsor_uri': 'https://api.propublica.org/congress/v1/members/C001078.json',
#   'gpo_pdf_uri': None,
#   'congressdotgov_url': 'https://www.congress.gov/bill/117th-congress/house-bill/8956',
#   'govtrack_url': 'https://www.govtrack.us/congress/bills/117/hr8956',
#   'introduced_date': '2022-09-22',
#   'active': True,
#   'last_vote': None,
#   'house_passage': None,
#   'senate_passage': None,
#   'enacted': None,
#   'vetoed': None,
#   'cosponsors': 1,
#   'cosponsors_by_party': {'R': 1},
#   'committees': 'Senate Homeland Security and Governmental Affairs Committee',
#   'committee_codes': ['SSGA', 'HSGO'],
#   'subcommittee_codes': [],
#   'primary_subject': 'Government Operations and Politics',
#   'summary': 'FedRAMP Authorization Act This bill provides statutory authority for the Federal Risk and Authorization Management Program (FedRAMP) within the General Services Administration (GSA). The GSA must establish a government-wide program that provides the authoritative standardized approach to security assessment and authorization for cloud computing products and services that process unclassified information used by agencies. Agencies must ensure that their cloud computing services meet GSA requirements. The Government Accountability Office must report to Congress assessing  the costs incurred by agencies and cloud service providers relating to the issuance of FedRAMP authorizations, the extent to which agencies have processes in place to continuously monitor the implementation of cloud computing products and services operating as federal information systems,  how often and for which categories of products and services agencies use FedRAMP authorizations, and the unique costs and potential burdens incurred by cloud computing companies that are small business concerns as a part of the FedRAMP authorization process.  The bill establishes the Federal Secure Cloud Advisory Committee.',
#   'summary_short': 'FedRAMP Authorization Act This bill provides statutory authority for the Federal Risk and Authorization Management Program (FedRAMP) within the General Services Administration (GSA). The GSA must establish a government-wide program that provides the authoritative standardized approach to security assessment and authorization for cloud computing products and services that process unclassified information used by agencies. Agencies must ensure that their cloud computing services meet GSA requir...',
#   'latest_major_action_date': '2022-10-11',
#   'latest_major_action': 'Received in the Senate and Read twice and referred to the Committee on Homeland Security and Governmental Affairs.'},
#  {'_id': ObjectId('63764dcce6cbfc0792a0cfd7'),
#   'bill_id': 'hr8955-117',
#   'bill_slug': 'hr8955',
#   'bill_type': 'hr',
#   'number': 'H.R.8955',
#   'bill_uri': 'https://api.propublica.org/congress/v1/117/bills/hr8955.json',
#   'title': 'To counter Russian influence and aggression in Ukraine.',
#   'short_title': 'Ukrainian Territorial Integrity Act',
#   'sponsor_title': 'Rep.',
#   'sponsor_id': 'C001078',
#   'sponsor_name': 'Gerald E. Connolly',
#   'sponsor_state': 'VA',
#   'sponsor_party': 'D',
#   'sponsor_uri': 'https://api.propublica.org/congress/v1/members/C001078.json',
#   'gpo_pdf_uri': None,
#   'congressdotgov_url': 'https://www.congress.gov/bill/117th-congress/house-bill/8955',
#   'govtrack_url': 'https://www.govtrack.us/congress/bills/117/hr8955',
#   'introduced_date': '2022-09-22',
#   'active': False,
#   'last_vote': None,
#   'house_passage': None,
#   'senate_passage': None,
#   'enacted': None,
#   'vetoed': None,
#   'cosponsors': 7,
#   'cosponsors_by_party': {'R': 1, 'D': 6},
#   'committees': 'House Foreign Affairs Committee',
#   'committee_codes': ['HSFA'],
#   'subcommittee_codes': [],
#   'primary_subject': 'International Affairs',
#   'summary': '',
#   'summary_short': '',
#   'latest_major_action_date': '2022-09-22',
#   'latest_major_action': 'Referred to the House Committee on Foreign Affairs.'},
#  {'_id': ObjectId('63764dcce6cbfc0792a0d001'),
#   'bill_id': 'hr8933-117',
#   'bill_slug': 'hr8933',
#   'bill_type': 'hr',
#   'number': 'H.R.8933',
#   'bill_uri': 'https://api.propublica.org/congress/v1/117/bills/hr8933.json',
#   'title': 'To amend chapter 6 of title 5, United States Code (commonly known as the "Regulatory Flexibility Act"), to ensure complete analysis of potential impacts on small entities of rules, and for other purposes.',
#   'short_title': 'Small Business Regulatory Flexibility Improvements Act',
#   'sponsor_title': 'Rep.',
#   'sponsor_id': 'C001118',
#   'sponsor_name': 'Ben Cline',
#   'sponsor_state': 'VA',
#   'sponsor_party': 'R',
#   'sponsor_uri': 'https://api.propublica.org/congress/v1/members/C001118.json',
#   'gpo_pdf_uri': None,
#   'congressdotgov_url': 'https://www.congress.gov/bill/117th-congress/house-bill/8933',
#   'govtrack_url': 'https://www.govtrack.us/congress/bills/117/hr8933',
#   'introduced_date': '2022-09-21',
#   'active': False,
#   'last_vote': None,
#   'house_passage': None,
#   'senate_passage': None,
#   'enacted': None,
#   'vetoed': None,
#   'cosponsors': 1,
#   'cosponsors_by_party': {'R': 1},
#   'committees': 'House Oversight and Reform Committee',
#   'committee_codes': ['HSJU'],
#   'subcommittee_codes': [],
#   'primary_subject': 'Government Operations and Politics',
#   'summary': '',
#   'summary_short': '',
#   'latest_major_action_date': '2022-09-21',
#   'latest_major_action': 'Referred to the Committee on the Judiciary, and in addition to the Committees on Small Business, and Oversight and Reform, for a period to be subsequently determined by the Speaker, in each case for consideration of such provisions as fall within the jurisdiction of the committee concerned.'},
#  {'_id': ObjectId('63764dcce6cbfc0792a0d00a'),
#   'bill_id': 'hr8935-117',
#   'bill_slug': 'hr8935',
#   'bill_type': 'hr',
#   'number': 'H.R.8935',
#   'bill_uri': 'https://api.propublica.org/congress/v1/117/bills/hr8935.json',
#   'title': 'To amend the Labor-Management Reporting and Disclosure Act of 1959 to provide whistleblower protection for union employees.',
#   'short_title': 'Union Integrity Act',
#   'sponsor_title': 'Rep.',
#   'sponsor_id': 'G000595',
#   'sponsor_name': 'Robert Good',
#   'sponsor_state': 'VA',
#   'sponsor_party': 'R',
#   'sponsor_uri': 'https://api.propublica.org/congress/v1/members/G000595.json',
#   'gpo_pdf_uri': None,
#   'congressdotgov_url': 'https://www.congress.gov/bill/117th-congress/house-bill/8935',
#   'govtrack_url': 'https://www.govtrack.us/congress/bills/117/hr8935',
#   'introduced_date': '2022-09-21',
#   'active': False,
#   'last_vote': None,
#   'house_passage': None,
#   'senate_passage': None,
#   'enacted': None,
#   'vetoed': None,
#   'cosponsors': 5,
#   'cosponsors_by_party': {'R': 5},
#   'committees': 'House Education and Labor Committee',
#   'committee_codes': ['HSED'],
#   'subcommittee_codes': [],
#   'primary_subject': 'Labor and Employment',
#   'summary': '',
#   'summary_short': '',
#   'latest_major_action_date': '2022-09-21',
#   'latest_major_action': 'Referred to the House Committee on Education and Labor.'},
#  {'_id': ObjectId('63764dcce6cbfc0792a0d038'),
#   'bill_id': 'hr8929-117',
#   'bill_slug': 'hr8929',
#   'bill_type': 'hr',
#   'number': 'H.R.8929',
#   'bill_uri': 'https://api.propublica.org/congress/v1/117/bills/hr8929.json',
#   'title': 'To designate the Cold War Museum located at 7142 Lineweaver Road, Warrenton, Virginia, as the "National Cold War Museum of the United States", and for other purposes.',
#   'short_title': 'To designate the Cold War Museum located at 7142 Lineweaver Road, Warrenton, Virginia, as the "National Cold War Museum of the United States", and for other purposes.',
#   'sponsor_title': 'Rep.',
#   'sponsor_id': 'W000804',
#   'sponsor_name': 'Robert J. Wittman',
#   'sponsor_state': 'VA',
#   'sponsor_party': 'R',
#   'sponsor_uri': 'https://api.propublica.org/congress/v1/members/W000804.json',
#   'gpo_pdf_uri': None,
#   'congressdotgov_url': 'https://www.congress.gov/bill/117th-congress/house-bill/8929',
#   'govtrack_url': 'https://www.govtrack.us/congress/bills/117/hr8929',
#   'introduced_date': '2022-09-20',
#   'active': False,
#   'last_vote': None,
#   'house_passage': None,
#   'senate_passage': None,
#   'enacted': None,
#   'vetoed': None,
#   'cosponsors': 4,
#   'cosponsors_by_party': {'D': 1, 'R': 3},
#   'committees': 'House Armed Services Committee',
#   'committee_codes': ['HSAS'],
#   'subcommittee_codes': [],
#   'primary_subject': 'Arts, Culture, Religion',
#   'summary': 'This bill designates the Cold War Museum located at 7142 Lineweaver Road, Warrenton, Virginia, as the National Cold War Museum of the United States. ',
#   'summary_short': 'This bill designates the Cold War Museum located at 7142 Lineweaver Road, Warrenton, Virginia, as the National Cold War Museum of the United States. ',
#   'latest_major_action_date': '2022-09-20',
#   'latest_major_action': 'Referred to the House Committee on Armed Services.'},
#  {'_id': ObjectId('63764dcce6cbfc0792a0d039'),
#   'bill_id': 'hr8927-117',
#   'bill_slug': 'hr8927',
#   'bill_type': 'hr',
#   'number': 'H.R.8927',
#   'bill_uri': 'https://api.propublica.org/congress/v1/117/bills/hr8927.json',
#   'title': 'To amend the Ethics in Government Act of 1978 to require the electronic filing of all public financial disclosure forms, and for other purposes.',
#   'short_title': 'Easy to READ Act',
#   'sponsor_title': 'Rep.',
#   'sponsor_id': 'S001209',
#   'sponsor_name': 'Abigail Spanberger',
#   'sponsor_state': 'VA',
#   'sponsor_party': 'D',
#   'sponsor_uri': 'https://api.propublica.org/congress/v1/members/S001209.json',
#   'gpo_pdf_uri': None,
#   'congressdotgov_url': 'https://www.congress.gov/bill/117th-congress/house-bill/8927',
#   'govtrack_url': 'https://www.govtrack.us/congress/bills/117/hr8927',
#   'introduced_date': '2022-09-20',
#   'active': False,
#   'last_vote': None,
#   'house_passage': None,
#   'senate_passage': None,
#   'enacted': None,
#   'vetoed': None,
#   'cosponsors': 1,
#   'cosponsors_by_party': {'R': 1},
#   'committees': 'House Committee on House Administration',
#   'committee_codes': ['HSHA'],
#   'subcommittee_codes': [],
#   'primary_subject': 'Congress',
#   'summary': '',
#   'summary_short': '',
#   'latest_major_action_date': '2022-09-20',
#   'latest_major_action': 'Referred to the House Committee on House Administration.'},
#  {'_id': ObjectId('63764dcde6cbfc0792a0d0af'),
#   'bill_id': 'hr8847-117',
#   'bill_slug': 'hr8847',
#   'bill_type': 'hr',
#   'number': 'H.R.8847',
#   'bill_uri': 'https://api.propublica.org/congress/v1/117/bills/hr8847.json',
#   'title': 'To amend the Natural Gas Act to bolster fairness and transparency in consideration of interstate natural gas pipelines, to provide for greater public input opportunities, and for other purposes.',
#   'short_title': 'Pipeline Fairness and Transparency Act',
#   'sponsor_title': 'Rep.',
#   'sponsor_id': 'G000568',
#   'sponsor_name': 'Morgan Griffith',
#   'sponsor_state': 'VA',
#   'sponsor_party': 'R',
#   'sponsor_uri': 'https://api.propublica.org/congress/v1/members/G000568.json',
#   'gpo_pdf_uri': None,
#   'congressdotgov_url': 'https://www.congress.gov/bill/117th-congress/house-bill/8847',
#   'govtrack_url': 'https://www.govtrack.us/congress/bills/117/hr8847',
#   'introduced_date': '2022-09-15',
#   'active': False,
#   'last_vote': None,
#   'house_passage': None,
#   'senate_passage': None,
#   'enacted': None,
#   'vetoed': None,
#   'cosponsors': 1,
#   'cosponsors_by_party': {'R': 1},
#   'committees': 'House Energy and Commerce Committee',
#   'committee_codes': ['HSIF'],
#   'subcommittee_codes': [],
#   'primary_subject': 'Energy',
#   'summary': '',
#   'summary_short': '',
#   'latest_major_action_date': '2022-09-15',
#   'latest_major_action': 'Referred to the House Committee on Energy and Commerce.'},
#  {'_id': ObjectId('63764dcee6cbfc0792a0d11e'),
#   'bill_id': 'hr8805-117',
#   'bill_slug': 'hr8805',
#   'bill_type': 'hr',
#   'number': 'H.R.8805',
#   'bill_uri': 'https://api.propublica.org/congress/v1/117/bills/hr8805.json',
#   'title': 'To amend titles XVIII and XIX of the Social Security Act with respect to nursing facility requirements, and for other purposes.',
#   'short_title': 'Ensuring Seniors’ Access to Quality Care Act',
#   'sponsor_title': 'Rep.',
#   'sponsor_id': 'C001078',
#   'sponsor_name': 'Gerald E. Connolly',
#   'sponsor_state': 'VA',
#   'sponsor_party': 'D',
#   'sponsor_uri': 'https://api.propublica.org/congress/v1/members/C001078.json',
#   'gpo_pdf_uri': None,
#   'congressdotgov_url': 'https://www.congress.gov/bill/117th-congress/house-bill/8805',
#   'govtrack_url': 'https://www.govtrack.us/congress/bills/117/hr8805',
#   'introduced_date': '2022-09-13',
#   'active': False,
#   'last_vote': None,
#   'house_passage': None,
#   'senate_passage': None,
#   'enacted': None,
#   'vetoed': None,
#   'cosponsors': 3,
#   'cosponsors_by_party': {'R': 2, 'D': 1},
#   'committees': 'House Ways and Means Committee',
#   'committee_codes': ['HSIF'],
#   'subcommittee_codes': [],
#   'primary_subject': 'Health',
#   'summary': "Ensuring Seniors' Access to Quality Care Act This bill repeals certain restrictions under Medicare and Medicaid that prohibit the approval of nurse-aide training and competency evaluation programs in skilled nursing facilities that have been subject to specified regulatory actions (e.g., civil penalties) for substandard quality of care. The Centers for Medicare &amp; Medicaid Services (CMS) must still disapprove such programs for up to two years; however, the CMS must rescind the disapproval upon completion of corrective action and may require additional oversight of the program for purposes of rescission. The bill also allows Medicaid and Medicare providers (e.g., skilled nursing facilities) to access, through the National Practitioner Data Bank, disciplinary information for affiliated physicians and other health care practitioners, as reported by state licensing authorities.",
#   'summary_short': 'Ensuring Seniors&#39; Access to Quality Care Act This bill repeals certain restrictions under Medicare and Medicaid that prohibit the approval of nurse-aide training and competency evaluation programs in skilled nursing facilities that have been subject to specified regulatory actions (e.g., civil penalties) for substandard quality of care. The Centers for Medicare &amp;amp; Medicaid Services (CMS) must still disapprove such programs for up to two years; however, the CMS must rescind the disapproval ...',
#   'latest_major_action_date': '2022-09-13',
#   'latest_major_action': 'Referred to the Committee on Energy and Commerce, and in addition to the Committee on Ways and Means, for a period to be subsequently determined by the Speaker, in each case for consideration of such provisions as fall within the jurisdiction of the committee concerned.'},
#  {'_id': ObjectId('63764dcfe6cbfc0792a0d13e'),
#   'bill_id': 'hr8781-117',
#   'bill_slug': 'hr8781',
#   'bill_type': 'hr',
#   'number': 'H.R.8781',
#   'bill_uri': 'https://api.propublica.org/congress/v1/117/bills/hr8781.json',
#   'title': 'To direct the Postal Regulatory Commission to review and modify market-dominant ratemaking system rules as a result of the enactment of the USPS Fairness Act, and for other purposes.',
#   'short_title': 'Ensuring Accurate Postal Rates Act',
#   'sponsor_title': 'Rep.',
#   'sponsor_id': 'C001078',
#   'sponsor_name': 'Gerald E. Connolly',
#   'sponsor_state': 'VA',
#   'sponsor_party': 'D',
#   'sponsor_uri': 'https://api.propublica.org/congress/v1/members/C001078.json',
#   'gpo_pdf_uri': None,
#   'congressdotgov_url': 'https://www.congress.gov/bill/117th-congress/house-bill/8781',
#   'govtrack_url': 'https://www.govtrack.us/congress/bills/117/hr8781',
#   'introduced_date': '2022-09-09',
#   'active': False,
#   'last_vote': None,
#   'house_passage': None,
#   'senate_passage': None,
#   'enacted': None,
#   'vetoed': None,
#   'cosponsors': 4,
#   'cosponsors_by_party': {'R': 2, 'D': 2},
#   'committees': 'House Oversight and Reform Committee',
#   'committee_codes': ['HSGO'],
#   'subcommittee_codes': [],
#   'primary_subject': 'Government Operations and Politics',
#   'summary': 'Ensuring Accurate Postal Rates Act This bill directs the Postal Regulatory Commission to review and potentially modify the market-dominant ratemaking system rules in light of the USPS Fairness Act, which canceled unpaid U.S. Postal Service obligations.',
#   'summary_short': 'Ensuring Accurate Postal Rates Act This bill directs the Postal Regulatory Commission to review and potentially modify the market-dominant ratemaking system rules in light of the USPS Fairness Act, which canceled unpaid U.S. Postal Service obligations.',
#   'latest_major_action_date': '2022-09-09',
#   'latest_major_action': 'Referred to the House Committee on Oversight and Reform.'},
#  {'_id': ObjectId('63764dcfe6cbfc0792a0d185'),
#   'bill_id': 'hr8767-117',
#   'bill_slug': 'hr8767',
#   'bill_type': 'hr',
#   'number': 'H.R.8767',
#   'bill_uri': 'https://api.propublica.org/congress/v1/117/bills/hr8767.json',
#   'title': 'To establish a private right of action for parents with respect to the teaching of racial discrimination theory and other actions by covered schools, and for other purposes.',
#   'short_title': 'Empowering Parents Act',
#   'sponsor_title': 'Rep.',
#   'sponsor_id': 'G000595',
#   'sponsor_name': 'Robert Good',
#   'sponsor_state': 'VA',
#   'sponsor_party': 'R',
#   'sponsor_uri': 'https://api.propublica.org/congress/v1/members/G000595.json',
#   'gpo_pdf_uri': None,
#   'congressdotgov_url': 'https://www.congress.gov/bill/117th-congress/house-bill/8767',
#   'govtrack_url': 'https://www.govtrack.us/congress/bills/117/hr8767',
#   'introduced_date': '2022-09-02',
#   'active': False,
#   'last_vote': None,
#   'house_passage': None,
#   'senate_passage': None,
#   'enacted': None,
#   'vetoed': None,
#   'cosponsors': 5,
#   'cosponsors_by_party': {'R': 5},
#   'committees': 'House Education and Labor Committee',
#   'committee_codes': ['HSED'],
#   'subcommittee_codes': [],
#   'primary_subject': 'Education',
#   'summary': 'Empowering Parents Act This bill prohibits certain actions by elementary and secondary schools.  Specifically, the bill prohibits schools from  compelling a teacher or student to adopt, affirm, adhere to, or profess racial discrimination theory or any idea in violation of Title IV or Title VI of the Civil Rights Act of 1964; compelling a student to observe or espouse obscene or sexual materials without parental consent; instructing or requiring an employee to refer to a student using a pronoun not associated with the biological sex of the student without parental consent; acting as the agent of a parent for purposes of providing verifiable parental consent or receiving a notice or other information required to be provided to a parent; or neglecting to report sexual assault or sexual harassment on school property to the appropriate law enforcement authorities.   A parent aggrieved by conduct prohibited under the bill may commerce a civil action against the school.',
#   'summary_short': 'Empowering Parents Act This bill prohibits certain actions by elementary and secondary schools.  Specifically, the bill prohibits schools from  compelling a teacher or student to adopt, affirm, adhere to, or profess racial discrimination theory or any idea in violation of Title IV or Title VI of the Civil Rights Act of 1964; compelling a student to observe or espouse obscene or sexual materials without parental consent; instructing or requiring an employee to refer to a student using a pronou...',
#   'latest_major_action_date': '2022-09-02',
#   'latest_major_action': 'Referred to the House Committee on Education and Labor.'},
#  {'_id': ObjectId('63764dcfe6cbfc0792a0d19f'),
#   'bill_id': 'hr8745-117',
#   'bill_slug': 'hr8745',
#   'bill_type': 'hr',
#   'number': 'H.R.8745',
#   'bill_uri': 'https://api.propublica.org/congress/v1/117/bills/hr8745.json',
#   'title': 'To direct the Secretary of Health and Human Services to maintain a National Concussion and Traumatic Brain Injury Clearinghouse.',
#   'short_title': 'National Concussion and Traumatic Brain Injury Clearinghouse Act of 2022',
#   'sponsor_title': 'Rep.',
#   'sponsor_id': 'C001078',
#   'sponsor_name': 'Gerald E. Connolly',
#   'sponsor_state': 'VA',
#   'sponsor_party': 'D',
#   'sponsor_uri': 'https://api.propublica.org/congress/v1/members/C001078.json',
#   'gpo_pdf_uri': None,
#   'congressdotgov_url': 'https://www.congress.gov/bill/117th-congress/house-bill/8745',
#   'govtrack_url': 'https://www.govtrack.us/congress/bills/117/hr8745',
#   'introduced_date': '2022-08-26',
#   'active': False,
#   'last_vote': None,
#   'house_passage': None,
#   'senate_passage': None,
#   'enacted': None,
#   'vetoed': None,
#   'cosponsors': 0,
#   'cosponsors_by_party': {},
#   'committees': 'House Energy and Commerce Committee',
#   'committee_codes': ['HSIF'],
#   'subcommittee_codes': [],
#   'primary_subject': 'Health',
#   'summary': 'National Concussion and Traumatic Brain Injury Clearinghouse Act of 2022 This bill establishes a clearinghouse for information (e.g., best practices and research) about concussions and traumatic brain injuries for medical professionals, patients, and other stakeholders. The Department of Health and Human Services and the Centers for Disease Control and Prevention must maintain the clearinghouse.',
#   'summary_short': 'National Concussion and Traumatic Brain Injury Clearinghouse Act of 2022 This bill establishes a clearinghouse for information (e.g., best practices and research) about concussions and traumatic brain injuries for medical professionals, patients, and other stakeholders. The Department of Health and Human Services and the Centers for Disease Control and Prevention must maintain the clearinghouse.',
#   'latest_major_action_date': '2022-08-26',
#   'latest_major_action': 'Referred to the House Committee on Energy and Commerce.'},
#  {'_id': ObjectId('63764dd0e6cbfc0792a0d1b4'),
#   'bill_id': 'hr8723-117',
#   'bill_slug': 'hr8723',
#   'bill_type': 'hr',
#   'number': 'H.R.8723',
#   'bill_uri': 'https://api.propublica.org/congress/v1/117/bills/hr8723.json',
#   'title': 'To amend the Energy Act of 2020 to require the Secretary of Energy to establish a program to accelerate the availability of commercially produced high-assay, low-enriched uranium in the United States and to make high-assay, low-enriched uranium produced from Department of Energy inventories available for use in advanced nuclear reactors, and for other purposes.',
#   'short_title': 'Fueling Our Nuclear Future Act of 2022',
#   'sponsor_title': 'Rep.',
#   'sponsor_id': 'L000591',
#   'sponsor_name': 'Elaine Luria',
#   'sponsor_state': 'VA',
#   'sponsor_party': 'D',
#   'sponsor_uri': 'https://api.propublica.org/congress/v1/members/L000591.json',
#   'gpo_pdf_uri': None,
#   'congressdotgov_url': 'https://www.congress.gov/bill/117th-congress/house-bill/8723',
#   'govtrack_url': 'https://www.govtrack.us/congress/bills/117/hr8723',
#   'introduced_date': '2022-08-16',
#   'active': False,
#   'last_vote': None,
#   'house_passage': None,
#   'senate_passage': None,
#   'enacted': None,
#   'vetoed': None,
#   'cosponsors': 1,
#   'cosponsors_by_party': {'R': 1},
#   'committees': 'House Energy and Commerce Committee',
#   'committee_codes': ['HSSY'],
#   'subcommittee_codes': [],
#   'primary_subject': 'Energy',
#   'summary': '',
#   'summary_short': '',
#   'latest_major_action_date': '2022-08-16',
#   'latest_major_action': 'Referred to the Committee on Science, Space, and Technology, and in addition to the Committee on Energy and Commerce, for a period to be subsequently determined by the Speaker, in each case for consideration of such provisions as fall within the jurisdiction of the committee concerned.'},
#  {'_id': ObjectId('63764dd0e6cbfc0792a0d1ce'),
#   'bill_id': 'hr8702-117',
#   'bill_slug': 'hr8702',
#   'bill_type': 'hr',
#   'number': 'H.R.8702',
#   'bill_uri': 'https://api.propublica.org/congress/v1/117/bills/hr8702.json',
#   'title': 'To prohibit the implementation of the proposed rule entitled "Nondiscrimination in Health Programs and Activities".',
#   'short_title': 'Taxpayers Support Life Act',
#   'sponsor_title': 'Rep.',
#   'sponsor_id': 'C001118',
#   'sponsor_name': 'Ben Cline',
#   'sponsor_state': 'VA',
#   'sponsor_party': 'R',
#   'sponsor_uri': 'https://api.propublica.org/congress/v1/members/C001118.json',
#   'gpo_pdf_uri': None,
#   'congressdotgov_url': 'https://www.congress.gov/bill/117th-congress/house-bill/8702',
#   'govtrack_url': 'https://www.govtrack.us/congress/bills/117/hr8702',
#   'introduced_date': '2022-08-12',
#   'active': False,
#   'last_vote': None,
#   'house_passage': None,
#   'senate_passage': None,
#   'enacted': None,
#   'vetoed': None,
#   'cosponsors': 45,
#   'cosponsors_by_party': {'R': 45},
#   'committees': 'House Energy and Commerce Committee',
#   'committee_codes': ['HSIF'],
#   'subcommittee_codes': [],
#   'primary_subject': 'Health',
#   'summary': 'Taxpayers Support Life Act This bill prohibits the Department of Health and Human Services (HHS) from finalizing, implementing, administering, or enforcing a proposed rule (published on August 4, 2022) that implements the statutory ban on discrimination in federally funded health programs and activities. Further, HHS may not use federal funds to contravene the administration or enforcement of the existing nondiscrimination rule, which became effective on June 19, 2020.',
#   'summary_short': 'Taxpayers Support Life Act This bill prohibits the Department of Health and Human Services (HHS) from finalizing, implementing, administering, or enforcing a proposed rule (published on August 4, 2022) that implements the statutory ban on discrimination in federally funded health programs and activities. Further, HHS may not use federal funds to contravene the administration or enforcement of the existing nondiscrimination rule, which became effective on June 19, 2020.',
#   'latest_major_action_date': '2022-08-12',
#   'latest_major_action': 'Referred to the House Committee on Energy and Commerce.'},
#  {'_id': ObjectId('63764dd3e6cbfc0792a0d321'),
#   'bill_id': 'hr8569-117',
#   'bill_slug': 'hr8569',
#   'bill_type': 'hr',
#   'number': 'H.R.8569',
#   'bill_uri': 'https://api.propublica.org/congress/v1/117/bills/hr8569.json',
#   'title': 'To require a direct causal nexus to remove certain cases to Federal court, and for other purposes.',
#   'short_title': 'Removal Adjustment Act of 2022',
#   'sponsor_title': 'Rep.',
#   'sponsor_id': 'L000591',
#   'sponsor_name': 'Elaine Luria',
#   'sponsor_state': 'VA',
#   'sponsor_party': 'D',
#   'sponsor_uri': 'https://api.propublica.org/congress/v1/members/L000591.json',
#   'gpo_pdf_uri': None,
#   'congressdotgov_url': 'https://www.congress.gov/bill/117th-congress/house-bill/8569',
#   'govtrack_url': 'https://www.govtrack.us/congress/bills/117/hr8569',
#   'introduced_date': '2022-07-28',
#   'active': False,
#   'last_vote': None,
#   'house_passage': None,
#   'senate_passage': None,
#   'enacted': None,
#   'vetoed': None,
#   'cosponsors': 0,
#   'cosponsors_by_party': {},
#   'committees': 'House Judiciary Committee',
#   'committee_codes': ['HSJU'],
#   'subcommittee_codes': [],
#   'primary_subject': 'Law',
#   'summary': '',
#   'summary_short': '',
#   'latest_major_action_date': '2022-07-28',
#   'latest_major_action': 'Referred to the House Committee on the Judiciary.'},
#  {'_id': ObjectId('63764dd3e6cbfc0792a0d322'),
#   'bill_id': 'hr8551-117',
#   'bill_slug': 'hr8551',
#   'bill_type': 'hr',
#   'number': 'H.R.8551',
#   'bill_uri': 'https://api.propublica.org/congress/v1/117/bills/hr8551.json',
#   'title': 'To improve air quality management and the safety of communities using the best available monitoring technology and data.',
#   'short_title': 'Technology Assessment for Air Quality Management Act of 2022',
#   'sponsor_title': 'Rep.',
#   'sponsor_id': 'M001200',
#   'sponsor_name': 'A. Donald McEachin',
#   'sponsor_state': 'VA',
#   'sponsor_party': 'D',
#   'sponsor_uri': 'https://api.propublica.org/congress/v1/members/M001200.json',
#   'gpo_pdf_uri': None,
#   'congressdotgov_url': 'https://www.congress.gov/bill/117th-congress/house-bill/8551',
#   'govtrack_url': 'https://www.govtrack.us/congress/bills/117/hr8551',
#   'introduced_date': '2022-07-28',
#   'active': False,
#   'last_vote': None,
#   'house_passage': None,
#   'senate_passage': None,
#   'enacted': None,
#   'vetoed': None,
#   'cosponsors': 7,
#   'cosponsors_by_party': {'D': 7},
#   'committees': 'House Energy and Commerce Committee',
#   'committee_codes': ['HSIF'],
#   'subcommittee_codes': [],
#   'primary_subject': 'Environmental Protection',
#   'summary': '',
#   'summary_short': '',
#   'latest_major_action_date': '2022-07-28',
#   'latest_major_action': 'Referred to the House Committee on Energy and Commerce.'},
#  {'_id': ObjectId('63764dd4e6cbfc0792a0d35a'),
#   'bill_id': 'hr8547-117',
#   'bill_slug': 'hr8547',
#   'bill_type': 'hr',
#   'number': 'H.R.8547',
#   'bill_uri': 'https://api.propublica.org/congress/v1/117/bills/hr8547.json',
#   'title': 'To direct the Secretary of Energy to require as a condition of any sale of crude oil from the Strategic Petroleum Reserve that the crude oil not be exported to certain countries, and for other purposes.',
#   'short_title': 'No Oil for CCP Act',
#   'sponsor_title': 'Rep.',
#   'sponsor_id': 'W000804',
#   'sponsor_name': 'Robert J. Wittman',
#   'sponsor_state': 'VA',
#   'sponsor_party': 'R',
#   'sponsor_uri': 'https://api.propublica.org/congress/v1/members/W000804.json',
#   'gpo_pdf_uri': None,
#   'congressdotgov_url': 'https://www.congress.gov/bill/117th-congress/house-bill/8547',
#   'govtrack_url': 'https://www.govtrack.us/congress/bills/117/hr8547',
#   'introduced_date': '2022-07-27',
#   'active': False,
#   'last_vote': None,
#   'house_passage': None,
#   'senate_passage': None,
#   'enacted': None,
#   'vetoed': None,
#   'cosponsors': 0,
#   'cosponsors_by_party': {},
#   'committees': 'House Energy and Commerce Committee',
#   'committee_codes': ['HSIF'],
#   'subcommittee_codes': [],
#   'primary_subject': 'Energy',
#   'summary': 'No Oil for CCP Act This bill bans exports of crude oil from the Strategic Petroleum Reserve (SPR) to China, North Korea, Iran, and other specified recipients. Specifically, the bill directs the Department of Energy to require as a condition of any sale of crude oil from the SPR that (1) the oil not be exported to such countries; and (2) the recipient of the oil is not under the ownership, control, or influence of the Chinese Communist Party.',
#   'summary_short': 'No Oil for CCP Act This bill bans exports of crude oil from the Strategic Petroleum Reserve (SPR) to China, North Korea, Iran, and other specified recipients. Specifically, the bill directs the Department of Energy to require as a condition of any sale of crude oil from the SPR that (1) the oil not be exported to such countries; and (2) the recipient of the oil is not under the ownership, control, or influence of the Chinese Communist Party.',
#   'latest_major_action_date': '2022-07-27',
#   'latest_major_action': 'Referred to the House Committee on Energy and Commerce.'},
#  {'_id': ObjectId('63764dd8e6cbfc0792a0d3f9'),
#   'bill_id': 'hr8472-117',
#   'bill_slug': 'hr8472',
#   'bill_type': 'hr',
#   'number': 'H.R.8472',
#   'bill_uri': 'https://api.propublica.org/congress/v1/117/bills/hr8472.json',
#   'title': 'To amend the Higher Education Act of 1965 to provide for Federal student loan reform.',
#   'short_title': 'LOAN Act of 2022',
#   'sponsor_title': 'Rep.',
#   'sponsor_id': 'L000591',
#   'sponsor_name': 'Elaine Luria',
#   'sponsor_state': 'VA',
#   'sponsor_party': 'D',
#   'sponsor_uri': 'https://api.propublica.org/congress/v1/members/L000591.json',
#   'gpo_pdf_uri': None,
#   'congressdotgov_url': 'https://www.congress.gov/bill/117th-congress/house-bill/8472',
#   'govtrack_url': 'https://www.govtrack.us/congress/bills/117/hr8472',
#   'introduced_date': '2022-07-21',
#   'active': False,
#   'last_vote': None,
#   'house_passage': None,
#   'senate_passage': None,
#   'enacted': None,
#   'vetoed': None,
#   'cosponsors': 0,
#   'cosponsors_by_party': {},
#   'committees': 'House Ways and Means Committee',
#   'committee_codes': ['HSED'],
#   'subcommittee_codes': [],
#   'primary_subject': 'Education',
#   'summary': '',
#   'summary_short': '',
#   'latest_major_action_date': '2022-07-21',
#   'latest_major_action': 'Referred to the Committee on Education and Labor, and in addition to the Committee on Ways and Means, for a period to be subsequently determined by the Speaker, in each case for consideration of such provisions as fall within the jurisdiction of the committee concerned.'},
#  {'_id': ObjectId('63764dd9e6cbfc0792a0d40b'),
#   'bill_id': 'hr8460-117',
#   'bill_slug': 'hr8460',
#   'bill_type': 'hr',
#   'number': 'H.R.8460',
#   'bill_uri': 'https://api.propublica.org/congress/v1/117/bills/hr8460.json',
#   'title': 'To remove obstacles to the ability of law enforcement officers to enforce gun safety laws, and for other purposes.',
#   'short_title': 'AIM Act',
#   'sponsor_title': 'Rep.',
#   'sponsor_id': 'B001292',
#   'sponsor_name': 'Donald Beyer',
#   'sponsor_state': 'VA',
#   'sponsor_party': 'D',
#   'sponsor_uri': 'https://api.propublica.org/congress/v1/members/B001292.json',
#   'gpo_pdf_uri': None,
#   'congressdotgov_url': 'https://www.congress.gov/bill/117th-congress/house-bill/8460',
#   'govtrack_url': 'https://www.govtrack.us/congress/bills/117/hr8460',
#   'introduced_date': '2022-07-21',
#   'active': False,
#   'last_vote': None,
#   'house_passage': None,
#   'senate_passage': None,
#   'enacted': None,
#   'vetoed': None,
#   'cosponsors': 8,
#   'cosponsors_by_party': {'D': 8},
#   'committees': 'House Judiciary Committee',
#   'committee_codes': ['HSJU'],
#   'subcommittee_codes': [],
#   'primary_subject': 'Crime and Law Enforcement',
#   'summary': '',
#   'summary_short': '',
#   'latest_major_action_date': '2022-07-21',
#   'latest_major_action': 'Referred to the House Committee on the Judiciary.'},
#  {'_id': ObjectId('63764dd9e6cbfc0792a0d40f'),
#   'bill_id': 'hr8466-117',
#   'bill_slug': 'hr8466',
#   'bill_type': 'hr',
#   'number': 'H.R.8466',
#   'bill_uri': 'https://api.propublica.org/congress/v1/117/bills/hr8466.json',
#   'title': 'To require the head of each agency to establish a plan relating to the safety of Federal employees and contractors physically present at certain worksites during a nationwide public health emergency declared for an infectious disease, and for other purposes.',
#   'short_title': 'Chai Suthammanont Remembrance Act of 2022',
#   'sponsor_title': 'Rep.',
#   'sponsor_id': 'C001078',
#   'sponsor_name': 'Gerald E. Connolly',
#   'sponsor_state': 'VA',
#   'sponsor_party': 'D',
#   'sponsor_uri': 'https://api.propublica.org/congress/v1/members/C001078.json',
#   'gpo_pdf_uri': None,
#   'congressdotgov_url': 'https://www.congress.gov/bill/117th-congress/house-bill/8466',
#   'govtrack_url': 'https://www.govtrack.us/congress/bills/117/hr8466',
#   'introduced_date': '2022-07-21',
#   'active': True,
#   'last_vote': '2022-09-29',
#   'house_passage': '2022-09-29',
# ...
#   'latest_major_action_date': '2021-01-04',
#   'latest_major_action': 'Referred to the Subcommittee on Oversight and Investigations.'},
#  {'_id': ObjectId('63764ef4e6cbfc0792a10f16'),
#   'bill_id': 'hr184-117',
#   'bill_slug': 'hr184',
#   'bill_type': 'hr',
#   'number': 'H.R.184',
#   'bill_uri': 'https://api.propublica.org/congress/v1/117/bills/hr184.json',
#   'title': 'To amend the Internal Revenue Code of 1986 to exclude from gross income certain combat zone compensation of civilian employees of the United States.',
#   'short_title': 'Federal Employee Combat Zone Tax Parity Act',
#   'sponsor_title': 'Rep.',
#   'sponsor_id': 'W000804',
#   'sponsor_name': 'Robert J. Wittman',
#   'sponsor_state': 'VA',
#   'sponsor_party': 'R',
#   'sponsor_uri': 'https://api.propublica.org/congress/v1/members/W000804.json',
#   'gpo_pdf_uri': None,
#   'congressdotgov_url': 'https://www.congress.gov/bill/117th-congress/house-bill/184',
#   'govtrack_url': 'https://www.govtrack.us/congress/bills/117/hr184',
#   'introduced_date': '2021-01-04',
#   'active': False,
#   'last_vote': None,
#   'house_passage': None,
#   'senate_passage': None,
#   'enacted': None,
#   'vetoed': None,
#   'cosponsors': 0,
#   'cosponsors_by_party': {},
#   'committees': 'House Ways and Means Committee',
#   'committee_codes': ['HSWM'],
#   'subcommittee_codes': [],
#   'primary_subject': 'Taxation',
#   'summary': 'Federal Employee Combat Zone Tax Parity Act This bill excludes from gross income, for income tax purposes, the compensation of a federal employee who served in a combat zone or was hospitalized as a result of wounds, disease, or injury incurred while serving in a combat zone. The bill terminates the exclusion two years after the end of combatant activities in such zone. ',
#   'summary_short': 'Federal Employee Combat Zone Tax Parity Act This bill excludes from gross income, for income tax purposes, the compensation of a federal employee who served in a combat zone or was hospitalized as a result of wounds, disease, or injury incurred while serving in a combat zone. The bill terminates the exclusion two years after the end of combatant activities in such zone. ',
#   'latest_major_action_date': '2021-01-04',
#   'latest_major_action': 'Referred to the House Committee on Ways and Means.'},
#  {'_id': ObjectId('63764ef4e6cbfc0792a10f17'),
#   'bill_id': 'hr182-117',
#   'bill_slug': 'hr182',
#   'bill_type': 'hr',
#   'number': 'H.R.182',
#   'bill_uri': 'https://api.propublica.org/congress/v1/117/bills/hr182.json',
#   'title': 'To improve the provision of health care by the Department of Veterans Affairs, and for other purposes.',
#   'short_title': 'Veteran’s Choice Accountability Act',
#   'sponsor_title': 'Rep.',
#   'sponsor_id': 'W000804',
#   'sponsor_name': 'Robert J. Wittman',
#   'sponsor_state': 'VA',
#   'sponsor_party': 'R',
#   'sponsor_uri': 'https://api.propublica.org/congress/v1/members/W000804.json',
#   'gpo_pdf_uri': None,
#   'congressdotgov_url': 'https://www.congress.gov/bill/117th-congress/house-bill/182',
#   'govtrack_url': 'https://www.govtrack.us/congress/bills/117/hr182',
#   'introduced_date': '2021-01-04',
#   'active': False,
#   'last_vote': None,
#   'house_passage': None,
#   'senate_passage': None,
#   'enacted': None,
#   'vetoed': None,
#   'cosponsors': 0,
#   'cosponsors_by_party': {},
#   'committees': 'House Veterans&#39; Affairs Committee',
#   'committee_codes': ['HSVR'],
#   'subcommittee_codes': ['HSVR03'],
#   'primary_subject': 'Armed Forces and National Security',
#   'summary': "Veteran's Choice Accountability Act This bill requires the Department of Veterans Affairs (VA) to evaluate VA programs that furnish hospital care, medical services, and nursing home care to ensure that the most intensively used specialized care programs are maintained as centers of excellence. The bill also requires the VA to submit an evaluation of the VA's implementation of the VA Budget and Choice Improvement Act.",
#   'summary_short': 'Veteran&#39;s Choice Accountability Act This bill requires the Department of Veterans Affairs (VA) to evaluate VA programs that furnish hospital care, medical services, and nursing home care to ensure that the most intensively used specialized care programs are maintained as centers of excellence. The bill also requires the VA to submit an evaluation of the VA&#39;s implementation of the VA Budget and Choice Improvement Act.',
#   'latest_major_action_date': '2021-02-17',
#   'latest_major_action': 'Referred to the Subcommittee on Health.'},
#  {'_id': ObjectId('63764ef4e6cbfc0792a10f19'),
#   'bill_id': 'hr183-117',
#   'bill_slug': 'hr183',
#   'bill_type': 'hr',
#   'number': 'H.R.183',
#   'bill_uri': 'https://api.propublica.org/congress/v1/117/bills/hr183.json',
#   'title': 'To direct the Secretary of Veterans Affairs to carry out a pilot program to promote and encourage collaboration between the Department of Veterans Affairs and nonprofit organizations and institutions of higher learning that provide administrative assistance to veterans.',
#   'short_title': 'Veterans Collaboration Act',
#   'sponsor_title': 'Rep.',
#   'sponsor_id': 'W000804',
#   'sponsor_name': 'Robert J. Wittman',
#   'sponsor_state': 'VA',
#   'sponsor_party': 'R',
#   'sponsor_uri': 'https://api.propublica.org/congress/v1/members/W000804.json',
#   'gpo_pdf_uri': None,
#   'congressdotgov_url': 'https://www.congress.gov/bill/117th-congress/house-bill/183',
#   'govtrack_url': 'https://www.govtrack.us/congress/bills/117/hr183',
#   'introduced_date': '2021-01-04',
#   'active': False,
#   'last_vote': None,
#   'house_passage': None,
#   'senate_passage': None,
#   'enacted': None,
#   'vetoed': None,
#   'cosponsors': 0,
#   'cosponsors_by_party': {},
#   'committees': 'House Veterans&#39; Affairs Committee',
#   'committee_codes': ['HSVR'],
#   'subcommittee_codes': ['HSVR09'],
#   'primary_subject': 'Armed Forces and National Security',
#   'summary': 'Veterans Collaboration Act This bill requires the Department of Veterans Affairs (VA) to carry out a two-year pilot program in states with the highest veteran populations to promote collaboration between the VA, nonprofit organizations, and institutions of higher learning.  The VA shall emphasize collaboration with (1) veterans service organizations that provide personnel with appropriate credentials to assist veterans in filing disability compensation claims and appeals with the VA, and (2) educational institutions that provide veterans with pro bono legal assistance.',
#   'summary_short': 'Veterans Collaboration Act This bill requires the Department of Veterans Affairs (VA) to carry out a two-year pilot program in states with the highest veteran populations to promote collaboration between the VA, nonprofit organizations, and institutions of higher learning.  The VA shall emphasize collaboration with (1) veterans service organizations that provide personnel with appropriate credentials to assist veterans in filing disability compensation claims and appeals with the VA, and (2) ...',
#   'latest_major_action_date': '2021-03-08',
#   'latest_major_action': 'Referred to the Subcommittee on Disability Assistance and Memorial Affairs.'},
#  {'_id': ObjectId('63764ef4e6cbfc0792a10f1a'),
#   'bill_id': 'hr179-117',
#   'bill_slug': 'hr179',
#   'bill_type': 'hr',
#   'number': 'H.R.179',
#   'bill_uri': 'https://api.propublica.org/congress/v1/117/bills/hr179.json',
#   'title': 'To prohibit the use of official funds for airline accommodations for Members of Congress which are not coach-class accommodations, and for other purposes.',
#   'short_title': 'No Congressional First Class Flights Act',
#   'sponsor_title': 'Rep.',
#   'sponsor_id': 'W000804',
#   'sponsor_name': 'Robert J. Wittman',
#   'sponsor_state': 'VA',
#   'sponsor_party': 'R',
#   'sponsor_uri': 'https://api.propublica.org/congress/v1/members/W000804.json',
#   'gpo_pdf_uri': None,
#   'congressdotgov_url': 'https://www.congress.gov/bill/117th-congress/house-bill/179',
#   'govtrack_url': 'https://www.govtrack.us/congress/bills/117/hr179',
#   'introduced_date': '2021-01-04',
#   'active': False,
#   'last_vote': None,
#   'house_passage': None,
#   'senate_passage': None,
#   'enacted': None,
#   'vetoed': None,
#   'cosponsors': 1,
#   'cosponsors_by_party': {'R': 1},
#   'committees': 'House Committee on House Administration',
#   'committee_codes': ['HSHA'],
#   'subcommittee_codes': [],
#   'primary_subject': 'Congress',
#   'summary': 'No Congressional First Class Flights Act This bill prohibits funds provided for the official travel expenses of a Member of Congress from being used for airline accommodations that are not coach-class, unless the accommodations are necessary to accommodate a medical disability or other special need.',
#   'summary_short': 'No Congressional First Class Flights Act This bill prohibits funds provided for the official travel expenses of a Member of Congress from being used for airline accommodations that are not coach-class, unless the accommodations are necessary to accommodate a medical disability or other special need.',
#   'latest_major_action_date': '2021-01-04',
#   'latest_major_action': 'Referred to the House Committee on House Administration.'},
#  {'_id': ObjectId('63764ef4e6cbfc0792a10f1b'),
#   'bill_id': 'hr185-117',
#   'bill_slug': 'hr185',
#   'bill_type': 'hr',
#   'number': 'H.R.185',
#   'bill_uri': 'https://api.propublica.org/congress/v1/117/bills/hr185.json',
#   'title': 'To amend title 10, United States Code, to include a single comprehensive disability examination as part of the required Department of Defense physical examination for separating members of the Armed Forces, and for other purposes.',
#   'short_title': 'Veterans Affairs Transfer of Information and Sharing of Disability Examination Procedures With DOD Doctors Act',
#   'sponsor_title': 'Rep.',
#   'sponsor_id': 'W000804',
#   'sponsor_name': 'Robert J. Wittman',
#   'sponsor_state': 'VA',
#   'sponsor_party': 'R',
#   'sponsor_uri': 'https://api.propublica.org/congress/v1/members/W000804.json',
#   'gpo_pdf_uri': None,
#   'congressdotgov_url': 'https://www.congress.gov/bill/117th-congress/house-bill/185',
#   'govtrack_url': 'https://www.govtrack.us/congress/bills/117/hr185',
#   'introduced_date': '2021-01-04',
#   'active': False,
#   'last_vote': None,
#   'house_passage': None,
#   'senate_passage': None,
#   'enacted': None,
#   'vetoed': None,
#   'cosponsors': 0,
#   'cosponsors_by_party': {},
#   'committees': 'House Veterans&#39; Affairs Committee',
#   'committee_codes': ['HSAS'],
#   'subcommittee_codes': ['HSVR09'],
#   'primary_subject': 'Armed Forces and National Security',
#   'summary': "Veterans Affairs Transfer of Information and Sharing of Disability Examination Procedures With DOD Doctors Act This bill addresses the sharing of medical information and disability examination procedures between the Departments of Defense (DOD) and Veterans Affairs (VA). It requires that if a member of the Armed Forces who is required to receive a physical examination upon separation from active duty and has or is believed to have a medical condition that may make the member eligible for veterans' disability compensation and benefits, the examination must be performed by a VA-certified health care provider. If the condition is discovered during the physical examination and the examining health care provider is not VA-certified, the examination must be completed by a VA-certified provider.  An eligibility determination made as part of such an examination shall be binding on the VA and be used as the basis for assigning the member's disability rating. The VA and DOD shall jointly establish a system to share data and maintain the medical and personnel records of Armed Forces members and veterans.",
#   'summary_short': 'Veterans Affairs Transfer of Information and Sharing of Disability Examination Procedures With DOD Doctors Act This bill addresses the sharing of medical information and disability examination procedures between the Departments of Defense (DOD) and Veterans Affairs (VA). It requires that if a member of the Armed Forces who is required to receive a physical examination upon separation from active duty and has or is believed to have a medical condition that may make the member eligible for vete...',
#   'latest_major_action_date': '2021-03-08',
#   'latest_major_action': 'Referred to the Subcommittee on Disability Assistance and Memorial Affairs.'},
#  {'_id': ObjectId('63764ef6e6cbfc0792a10f2b'),
#   'bill_id': 'hr21-117',
#   'bill_slug': 'hr21',
#   'bill_type': 'hr',
#   'number': 'H.R.21',
#   'bill_uri': 'https://api.propublica.org/congress/v1/117/bills/hr21.json',
#   'title': 'To enhance the innovation, security, and availability of cloud computing products and services used in the Federal Government by establishing the Federal Risk and Authorization Management Program within the General Services Administration and by establishing a risk management, authorization, and continuous monitoring process to enable the Federal Government to leverage cloud computing products and services using a risk-based approach consistent with the Federal Information Security Modernization Act of 2014 and cloud-based operations, and for other purposes.',
#   'short_title': 'FedRAMP Authorization Act',
#   'sponsor_title': 'Rep.',
#   'sponsor_id': 'C001078',
#   'sponsor_name': 'Gerald E. Connolly',
#   'sponsor_state': 'VA',
#   'sponsor_party': 'D',
#   'sponsor_uri': 'https://api.propublica.org/congress/v1/members/C001078.json',
#   'gpo_pdf_uri': None,
#   'congressdotgov_url': 'https://www.congress.gov/bill/117th-congress/house-bill/21',
#   'govtrack_url': 'https://www.govtrack.us/congress/bills/117/hr21',
#   'introduced_date': '2021-01-04',
#   'active': True,
#   'last_vote': None,
#   'house_passage': '2021-01-05',
#   'senate_passage': None,
#   'enacted': None,
#   'vetoed': None,
#   'cosponsors': 2,
#   'cosponsors_by_party': {'R': 2},
#   'committees': 'Senate Homeland Security and Governmental Affairs Committee',
#   'committee_codes': ['SSGA', 'HSGO'],
#   'subcommittee_codes': [],
#   'primary_subject': 'Government Operations and Politics',
#   'summary': 'Federal Risk and Authorization Management Program Authorization Act of 2021 or the FedRAMP Authorization Act This bill provides statutory authority for the Federal Risk and Authorization Management Program (FedRAMP) within the General Services Administration (GSA). The GSA must establish a government-wide program that provides the authoritative standardized approach to security assessment and authorization for cloud computing products and services that process unclassified information used by agencies. Agencies must ensure that their cloud computing services meet GSA requirements. The bill establishes the Joint Authorization Board to conduct security assessments of cloud computing services and issue provisional authorizations to operate to cloud service providers that meet FedRAMP security guidelines. The GSA shall (1) publish a report that includes an assessment of the cost incurred by agencies and cloud service providers related to the issuance of FedRAMP authorizations and provisional authorizations, (2) determine the requirements for certification of independent assessment organizations, and (3) establish the Federal Secure Cloud Advisory Committee.',
#   'summary_short': 'Federal Risk and Authorization Management Program Authorization Act of 2021 or the FedRAMP Authorization Act This bill provides statutory authority for the Federal Risk and Authorization Management Program (FedRAMP) within the General Services Administration (GSA). The GSA must establish a government-wide program that provides the authoritative standardized approach to security assessment and authorization for cloud computing products and services that process unclassified information used by...',
#   'latest_major_action_date': '2021-01-06',
#   'latest_major_action': 'Received in the Senate and Read twice and referred to the Committee on Homeland Security and Governmental Affairs.'}]

# %%
bills.create_index([('bill_text', 'text')])
#
# Out:
# 'bill_text_text'

# %%
myquery = bills.find({'$text': {'$search': 'robert good', '$caseSensitive': False}},
                     {'score': {'$meta': 'textScore'}})
myquery.sort([('score', {'$meta': 'textScore'})])
loads(dumps(myquery))
# Out:
# [{'_id': ObjectId('63764e31e6cbfc0792a0e626'),
#   'bill_id': 'hjres64-117',
#   'bill_slug': 'hjres64',
#   'bill_type': 'hjres',
#   'number': 'H.J.RES.64',
#   'bill_uri': 'https://api.propublica.org/congress/v1/117/bills/hjres64.json',
#   'title': 'Designating a "Slavery Remembrance Day" on August 20th, to serve as a reminder of the evils of slavery.',
#   'short_title': 'Original Slavery Remembrance Day Resolution',
#   'sponsor_title': 'Rep.',
#   'sponsor_id': 'G000553',
#   'sponsor_name': 'Al Green',
#   'sponsor_state': 'TX',
#   'sponsor_party': 'D',
#   'sponsor_uri': 'https://api.propublica.org/congress/v1/members/G000553.json',
#   'gpo_pdf_uri': None,
#   'congressdotgov_url': 'https://www.congress.gov/bill/117th-congress/house-joint-resolution/64',
#   'govtrack_url': 'https://www.govtrack.us/congress/bills/117/hjres64',
#   'introduced_date': '2021-11-17',
#   'active': False,
#   'last_vote': None,
#   'house_passage': None,
#   'senate_passage': None,
#   'enacted': None,
#   'vetoed': None,
#   'cosponsors': 85,
#   'cosponsors_by_party': {'D': 85},
#   'committees': 'House Oversight and Reform Committee',
#   'committee_codes': ['HSGO'],
#   'subcommittee_codes': [],
#   'primary_subject': 'Civil Rights and Liberties, Minority Issues',
#   'summary': 'Original Slavery Remembrance Day Resolution This joint resolution designates a Slavery Remembrance Day annually and condemns slavery and its progenies.',
#   'summary_short': 'Original Slavery Remembrance Day Resolution This joint resolution designates a Slavery Remembrance Day annually and condemns slavery and its progenies.',
#   'latest_major_action_date': '2021-11-17',
#   'latest_major_action': 'Referred to the House Committee on Oversight and Reform.',
#   'bill_text': 'Whereas this resolution may be cited as the Original Slavery Remembrance Day Resolution; Whereas the House of Representatives and the Senate recognize August 20th, as Slavery Remembrance Day and commemorate the lives of all enslaved people while also condemning the act and perpetuation of slavery in the United States of America and across the world; Whereas we posthumously recognize the following Members of Congress, who served during and after the Reconstruction era, as honorary cosponsors of this resolution: the Honorable Joseph Hayne Rainey (SC–01), Member of Congress from 1870 to 1879, Jefferson Franklin Long (GA–04), Member of Congress from January 1871 to March 1871, Robert Carlos De Large (SC–02), Member of Congress from 1871 to 1873, Robert Brown Elliott (SC–3), Member of Congress from 1871 to 1874, Benjamin Sterling Turner (AL–01), Member of Congress from 1871 to 1873, Josiah Thomas Walls (FL-At Large), Member of Congress from 1871 to 1876, Alonzo Jacob Ransier (SC–02), Member of Congress from 1873 to 1875, Richard Harvey Cain (SC-At Large), Member of Congress from 1873 to 1875 and 1877 to 1879, John Roy Lynch (MS–06), Member of Congress from 1873 to 1877 and 1882 to 1883, James Thomas Rapier (AL–02), Member of Congress from 1873 to 1875, Jeremiah Haralson (AL–01), Member of Congress from 1875 to 1877, John Adams Hyman (NC–02), Member of Congress from 1875 to 1877, Robert Smalls (SC–07), Member of Congress from 1875 to 1879 and 1882 to 1883 and 1884 to 1887, James Edward O’Hara (NC–02), Member of Congress from 1883 to 1887, Henry Plummer Cheatham (NC–02), Member of Congress from 1889 to 1893, John Mercer Langston (VA–04), Member of Congress from 1890 to 1891, Thomas Ezekiel Miller, Member of Congress from 1890 to 1891, George Washington Murray (SC–01), Member of Congress from 1893 to 1895 and 1896 to 1897, and George Henry White (NC–02), Member of Congress from 1897 to 1901; Whereas, on August 20, 1619, the first 20 enslaved Africans were brought to what is now Fort Monroe, then Point Comfort, in Hampton, Virginia against their will; Whereas the House of Representatives and the Senate recognize August 20th, as Slavery Remembrance Day and commemorate the lives of all enslaved people while also condemning the act and perpetuation of slavery in the United States of America and across the world; Whereas African tribal chiefs captured, enslaved, and sold their captives to transatlantic slave traders; Whereas, over the period of the Atlantic slave trade, from approximately 1526 to 1867, millions of humans were abducted and shipped from Africa, and 10,700,000 arrived in the Americas as personal property; Whereas the majority of enslaved Africans brought to British North America arrived between 1720 and 1780; Whereas about 6 percent of African captives were sent directly to British North America; Whereas, by 1825, the population of the United States included about one quarter of the people of African descent in what has been called the New World; Whereas the Middle Passage from West Africa to the West Indies was dangerous and horrific for enslaved people; Whereas the Middle Passage carried mothers, fathers, children, sisters, brothers, aunts, uncles, cousins, and individuals from all walks of life to slavery in the Americas; Whereas, although the sexes were separated, men, women, and children were kept naked, packed close together, and the men were chained for long periods; Whereas, according to some historians, about 12 percent of those who embarked did not survive the voyage; Whereas sharks followed the slave ships to feed on bodies of slaves thrown overboard; Whereas enslaved people suffered a variety of miserable and often fatal maladies due to the Atlantic slave trade, and to inhumane living and working conditions; Whereas infant and child mortality rates were twice as high among slave children as among Southern White children; Whereas enslaved people often worked from before sunup to after sundown, 6 to  ...
#   'score': 0.940893665158371},
#  {'_id': ObjectId('63764edde6cbfc0792a10d20'),
#   'bill_id': 's63-117',
#   'bill_slug': 's63',
#   'bill_type': 's',
#   'number': 'S.63',
#   'bill_uri': 'https://api.propublica.org/congress/v1/117/bills/s63.json',
#   'title': 'A bill to establish an Office of Emerging Markets within the Small Business Administration that will strengthen the development of small business concerns in emerging markets, including those owned by women, minorities, veterans, and those located in rural areas, and for other purposes.',
#   'short_title': 'Unlocking Opportunities in Emerging Markets Act of 2021',
#   'sponsor_title': 'Sen.',
#   'sponsor_id': 'C000141',
#   'sponsor_name': 'Benjamin L. Cardin',
#   'sponsor_state': 'MD',
#   'sponsor_party': 'D',
#   'sponsor_uri': 'https://api.propublica.org/congress/v1/members/C000141.json',
#   'gpo_pdf_uri': None,
#   'congressdotgov_url': 'https://www.congress.gov/bill/117th-congress/senate-bill/63',
#   'govtrack_url': 'https://www.govtrack.us/congress/bills/117/s63',
#   'introduced_date': '2021-01-27',
#   'active': False,
#   'last_vote': None,
#   'house_passage': None,
#   'senate_passage': None,
#   'enacted': None,
#   'vetoed': None,
#   'cosponsors': 3,
#   'cosponsors_by_party': {'D': 3},
#   'committees': 'Senate Small Business and Entrepreneurship Committee',
#   'committee_codes': ['SSSB'],
#   'subcommittee_codes': [],
#   'primary_subject': 'Commerce',
#   'summary': 'Unlocking Opportunities in Emerging Markets Act of 2021 This bill establishes the Office of Emerging Markets within the Small Business Administration to oversee the planning, coordination, implementation, evaluation, and improvement of efforts to enhance the economic well-being of small business concerns in emerging markets. ',
#   'summary_short': 'Unlocking Opportunities in Emerging Markets Act of 2021 This bill establishes the Office of Emerging Markets within the Small Business Administration to oversee the planning, coordination, implementation, evaluation, and improvement of efforts to enhance the economic well-being of small business concerns in emerging markets. ',
#   'latest_major_action_date': '2021-01-27',
#   'latest_major_action': 'Read twice and referred to the Committee on Small Business and Entrepreneurship.',
#   'bill_text': 'In recognition of the long and distinguished service rendered to the Nation by the Honorable Robert Joseph Dole, formerly a Senator and a Representative from the State of Kansas, his remains shall be permitted to lie in honor in the rotunda of the Capitol on December 9, 2021, and the Architect of the Capitol, under the direction of the President pro tempore of the Senate and the Speaker of the House of Representatives, shall take all necessary steps for the accomplishment of that purpose. The Architect of the Capitol is authorized and directed to transfer the catafalque which is situated in the Exhibition Hall of the Capitol Visitor Center to the rotunda of the Capitol so that such catafalque may be used in connection with services to be conducted there for the Honorable Robert Joseph Dole, formerly a Senator and a Representative from the State of Kansas.',
#   'score': 0.7714285714285714},
#  {'_id': ObjectId('63764e2fe6cbfc0792a0e4fb'),
#   'bill_id': 'hconres63-117',
#   'bill_slug': 'hconres63',
#   'bill_type': 'hconres',
#   'number': 'H.CON.RES.63',
#   'bill_uri': 'https://api.propublica.org/congress/v1/117/bills/hconres63.json',
#   'title': 'Permitting the remains of the late Honorable Robert Joseph Dole, formerly a Senator and a Representative from the State of Kansas, to lie in honor in the rotunda of the Capitol, and for other purposes.',
#   'short_title': 'Permitting the remains of the late Honorable Robert Joseph Dole, formerly a Senator and a Representative from the State of Kansas, to lie in honor in the rotunda of the Capitol, and for other purposes.',
#   'sponsor_title': 'Rep.',
#   'sponsor_id': 'E000298',
#   'sponsor_name': 'Ron Estes',
#   'sponsor_state': 'KS',
#   'sponsor_party': 'R',
#   'sponsor_uri': 'https://api.propublica.org/congress/v1/members/E000298.json',
#   'gpo_pdf_uri': None,
#   'congressdotgov_url': 'https://www.congress.gov/bill/117th-congress/house-concurrent-resolution/63',
#   'govtrack_url': 'https://www.govtrack.us/congress/bills/117/hconres63',
#   'introduced_date': '2021-12-07',
#   'active': False,
#   'last_vote': None,
#   'house_passage': None,
#   'senate_passage': None,
#   'enacted': None,
#   'vetoed': None,
#   'cosponsors': 2,
#   'cosponsors_by_party': {'R': 2},
#   'committees': 'House Committee on House Administration',
#   'committee_codes': ['HSHA'],
#   'subcommittee_codes': [],
#   'primary_subject': 'Congress',
#   'summary': 'This concurrent resolution authorizes the use of the Capitol rotunda on December 9, 2021, for the lying in honor of the remains of the Honorable Robert Dole, formerly a Senator and a Representative from Kansas. The resolution also directs the Architect of the Capitol to move the catafalque (a wooden platform) from the Capitol Visitor Center to the Capitol rotunda for use in connection with services for the Honorable Robert Dole.',
#   'summary_short': 'This concurrent resolution authorizes the use of the Capitol rotunda on December 9, 2021, for the lying in honor of the remains of the Honorable Robert Dole, formerly a Senator and a Representative from Kansas. The resolution also directs the Architect of the Capitol to move the catafalque (a wooden platform) from the Capitol Visitor Center to the Capitol rotunda for use in connection with services for the Honorable Robert Dole.',
#   'latest_major_action_date': '2021-12-07',
#   'latest_major_action': 'Referred to the House Committee on House Administration.',
#   'bill_text': 'In recognition of the long and distinguished service rendered to the Nation by the Honorable Robert Joseph Dole, formerly a Senator and a Representative from the State of Kansas, his remains shall be permitted to lie in honor in the rotunda of the Capitol on December 9, 2021, and the Architect of the Capitol, under the direction of the President pro tempore of the Senate and the Speaker of the House of Representatives, shall take all necessary steps for the accomplishment of that purpose. The Architect of the Capitol is authorized and directed to transfer the catafalque which is situated in the Exhibition Hall of the Capitol Visitor Center to the rotunda of the Capitol so that such catafalque may be used in connection with services to be conducted there for the Honorable Robert Joseph Dole, formerly a Senator and a Representative from the State of Kansas.',
#   'score': 0.7714285714285714},
#  {'_id': ObjectId('63764edee6cbfc0792a10d2f'),
#   'bill_id': 's66-117',
#   'bill_slug': 's66',
#   'bill_type': 's',
#   'number': 'S.66',
#   'bill_uri': 'https://api.propublica.org/congress/v1/117/bills/s66.json',
#   'title': 'A bill to require the Inter-Agency Task Force on Harmful Algal Blooms and Hypoxia to develop a plan for reducing, mitigating, and controlling harmful algal blooms and hypoxia in South Florida, and for other purposes.',
#   'short_title': 'South Florida Clean Coastal Waters Act of 2021',
#   'sponsor_title': 'Sen.',
#   'sponsor_id': 'R000595',
#   'sponsor_name': 'Marco Rubio',
#   'sponsor_state': 'FL',
#   'sponsor_party': 'R',
#   'sponsor_uri': 'https://api.propublica.org/congress/v1/members/R000595.json',
#   'gpo_pdf_uri': None,
#   'congressdotgov_url': 'https://www.congress.gov/bill/117th-congress/senate-bill/66',
#   'govtrack_url': 'https://www.govtrack.us/congress/bills/117/s66',
#   'introduced_date': '2021-01-27',
#   'active': True,
#   'last_vote': '2022-05-11',
#   'house_passage': '2022-05-11',
#   'senate_passage': '2022-03-08',
#   'enacted': '2022-06-16',
#   'vetoed': None,
#   'cosponsors': 1,
#   'cosponsors_by_party': {'R': 1},
#   'committees': 'Senate Commerce, Science, and Transportation Committee',
#   'committee_codes': ['SSCM'],
#   'subcommittee_codes': [],
#   'primary_subject': 'Environmental Protection',
#   'summary': 'South Florida Clean Coastal Waters Act of 2021 This bill addresses harmful algal blooms and hypoxia in the South Florida ecosystem. An algal bloom is a rapid growth of algae that may create toxic or hypoxic (severely low-oxygen) conditions that are harmful to humans, animals, aquatic ecosystems, and the economy. The Inter-Agency Task Force on Harmful Algal Blooms and Hypoxia must assess potential approaches to reduce harmful algal blooms and hypoxia in the ecosystem. The task force must also submit a plan, based on the assessment, for reducing, mitigating, and controlling harmful algal blooms and hypoxia in the region.',
#   'summary_short': 'South Florida Clean Coastal Waters Act of 2021 This bill addresses harmful algal blooms and hypoxia in the South Florida ecosystem. An algal bloom is a rapid growth of algae that may create toxic or hypoxic (severely low-oxygen) conditions that are harmful to humans, animals, aquatic ecosystems, and the economy. The Inter-Agency Task Force on Harmful Algal Blooms and Hypoxia must assess potential approaches to reduce harmful algal blooms and hypoxia in the ecosystem. The task force must also ...',
#   'latest_major_action_date': '2022-06-16',
#   'latest_major_action': 'Became Public Law No: 117-144.',
#   'bill_text': 'Whereas the preamble to the Universal Declaration of Human Rights says that disregard and contempt for human rights have resulted in barbarous acts which have outraged the conscience of humankind, and the advent of a world in which human beings shall enjoy freedom of speech and belief and freedom from fear and want has been proclaimed as the highest aspiration of the common people; Whereas the Constitution of the United Nations Educational, Scientific and Cultural Organization (UNESCO) reminds us that a peace based exclusively upon the political and economic arrangements of Governments would not be a peace which could secure the unanimous, lasting and sincere support of the peoples of the world, and the peace must therefore be founded, if it is not to fail, upon the intellectual and moral solidarity of mankind; Whereas the 2020 Global Peace Index found that peacefulness declined for the ninth time in 12 years, with 80 countries showing declining peacefulness scores; Whereas the 2020 Global Peace Index also noted that global violence cost $14.5 trillion in 2019; Whereas strengthening and supporting domestic and global efforts to study, discuss, teach, and develop techniques and methods to encourage and augment global peace efforts is a critical international goal; Whereas, on November 30, 1981, during the 77th plenary meeting, the United Nations General Assembly adopted a resolution to declare the third Tuesday of September as the International Day of Peace; Whereas nearly 20 years later, the United Nations General Assembly adopted A/RES/55/282, which officially designated September 21 as a global day to recognize and celebrate international cease-fire and nonviolence; Whereas, in 2001, the United Nations Economic and Social Council Organization proclaimed November 10 as World Science Day for Peace and Development; Whereas, on February 24, 2003, the United Nations General Assembly adopted a resolution declaring each May 29th as International Day of United Nations Peacekeepers, recognizing the significant sacrifices people have made and continue to make in pursuit of peace; Whereas, on December 22, 2005, the United Nations General Assembly adopted a resolution declaring December 20th International Human Solidarity Day and defined solidarity as a fundamental and universal value underlying modern human relations; Whereas, on June 15, 2007, the United Nations General Assembly adopted a resolution declaring October 2 as International Day of Non-Violence, extolling the virtues of nonviolent action such as protests, marches, vigils, and other acts of peaceful resistance; Whereas, on August 19, 2013, the United Nations General Assembly adopted a resolution declaring April 6th as the International Day of Sport for Development and Peace; Whereas, on February 2, 2017, the United Nations General Assembly adopted a resolution declaring December 12 as International Day of Neutrality; Whereas, on January 15, 2018, the United Nations General Assembly adopted a resolution declaring May 16 as International Day of Living Together in Peace, and affirmed that, in order to accomplish the goal of peace, we must eliminate all forms of discrimination and intolerance; Whereas, on December 12, 2018, the United Nations General Assembly adopted a resolution declaring April 24th International Day of Multilateralism and Diplomacy for Peace, recognizing that peace requires good-faith cooperation; Whereas, on July 25, 2019, the United Nations General Assembly adopted a resolution declaring April 5th as the International Day of Conscience in order to mobiliz[e] the efforts of the international community to promote peace, tolerance, inclusion, understanding and solidarity, in order to build a sustainable world of peace, solidarity and harmony; Whereas attaining peace involves the active and persistent process of persuading people of the benefits of peace, cooperation, tolerance, and nonviolence; Whereas peace is only attainable via a sustained co ...
#   'score': 0.75281425891182},
#  {'_id': ObjectId('63764e2ce6cbfc0792a0e3a4'),
#   'bill_id': 'hconres66-117',
#   'bill_slug': 'hconres66',
#   'bill_type': 'hconres',
#   'number': 'H.CON.RES.66',
#   'bill_uri': 'https://api.propublica.org/congress/v1/117/bills/hconres66.json',
#   'title': 'Recognizing international days of peace, coexistence, and cooperation.',
#   'short_title': 'Recognizing international days of peace, coexistence, and cooperation.',
#   'sponsor_title': 'Rep.',
#   'sponsor_id': 'W000788',
#   'sponsor_name': 'Nikema Williams',
#   'sponsor_state': 'GA',
#   'sponsor_party': 'D',
#   'sponsor_uri': 'https://api.propublica.org/congress/v1/members/W000788.json',
#   'gpo_pdf_uri': None,
#   'congressdotgov_url': 'https://www.congress.gov/bill/117th-congress/house-concurrent-resolution/66',
#   'govtrack_url': 'https://www.govtrack.us/congress/bills/117/hconres66',
#   'introduced_date': '2021-12-20',
#   'active': False,
#   'last_vote': None,
#   'house_passage': None,
#   'senate_passage': None,
#   'enacted': None,
#   'vetoed': None,
#   'cosponsors': 27,
#   'cosponsors_by_party': {'D': 27},
#   'committees': 'House Oversight and Reform Committee',
#   'committee_codes': ['HSGO'],
#   'subcommittee_codes': [],
#   'primary_subject': 'International Affairs',
#   'summary': 'This resolution recognizes the anniversaries of the International Day of Peace, Human Solidarity Day, the International Day of Living Together in Peace, and other specified international days.  The resolution also expresses that Congress commits to (1) encouraging the people of the United States to continue commemorating international days of peace, coexistence, and cooperation; and (2) supporting activities on such days that promote thoughtful, deliberative, and cooperative actions to achieve peace. ',
#   'summary_short': 'This resolution recognizes the anniversaries of the International Day of Peace, Human Solidarity Day, the International Day of Living Together in Peace, and other specified international days.  The resolution also expresses that Congress commits to (1) encouraging the people of the United States to continue commemorating international days of peace, coexistence, and cooperation; and (2) supporting activities on such days that promote thoughtful, deliberative, and cooperative actions to achiev...',
#   'latest_major_action_date': '2021-12-20',
#   'latest_major_action': 'Referred to the House Committee on Oversight and Reform.',
#   'bill_text': 'Whereas the preamble to the Universal Declaration of Human Rights says that disregard and contempt for human rights have resulted in barbarous acts which have outraged the conscience of humankind, and the advent of a world in which human beings shall enjoy freedom of speech and belief and freedom from fear and want has been proclaimed as the highest aspiration of the common people; Whereas the Constitution of the United Nations Educational, Scientific and Cultural Organization (UNESCO) reminds us that a peace based exclusively upon the political and economic arrangements of Governments would not be a peace which could secure the unanimous, lasting and sincere support of the peoples of the world, and the peace must therefore be founded, if it is not to fail, upon the intellectual and moral solidarity of mankind; Whereas the 2020 Global Peace Index found that peacefulness declined for the ninth time in 12 years, with 80 countries showing declining peacefulness scores; Whereas the 2020 Global Peace Index also noted that global violence cost $14.5 trillion in 2019; Whereas strengthening and supporting domestic and global efforts to study, discuss, teach, and develop techniques and methods to encourage and augment global peace efforts is a critical international goal; Whereas, on November 30, 1981, during the 77th plenary meeting, the United Nations General Assembly adopted a resolution to declare the third Tuesday of September as the International Day of Peace; Whereas nearly 20 years later, the United Nations General Assembly adopted A/RES/55/282, which officially designated September 21 as a global day to recognize and celebrate international cease-fire and nonviolence; Whereas, in 2001, the United Nations Economic and Social Council Organization proclaimed November 10 as World Science Day for Peace and Development; Whereas, on February 24, 2003, the United Nations General Assembly adopted a resolution declaring each May 29th as International Day of United Nations Peacekeepers, recognizing the significant sacrifices people have made and continue to make in pursuit of peace; Whereas, on December 22, 2005, the United Nations General Assembly adopted a resolution declaring December 20th International Human Solidarity Day and defined solidarity as a fundamental and universal value underlying modern human relations; Whereas, on June 15, 2007, the United Nations General Assembly adopted a resolution declaring October 2 as International Day of Non-Violence, extolling the virtues of nonviolent action such as protests, marches, vigils, and other acts of peaceful resistance; Whereas, on August 19, 2013, the United Nations General Assembly adopted a resolution declaring April 6th as the International Day of Sport for Development and Peace; Whereas, on February 2, 2017, the United Nations General Assembly adopted a resolution declaring December 12 as International Day of Neutrality; Whereas, on January 15, 2018, the United Nations General Assembly adopted a resolution declaring May 16 as International Day of Living Together in Peace, and affirmed that, in order to accomplish the goal of peace, we must eliminate all forms of discrimination and intolerance; Whereas, on December 12, 2018, the United Nations General Assembly adopted a resolution declaring April 24th International Day of Multilateralism and Diplomacy for Peace, recognizing that peace requires good-faith cooperation; Whereas, on July 25, 2019, the United Nations General Assembly adopted a resolution declaring April 5th as the International Day of Conscience in order to mobiliz[e] the efforts of the international community to promote peace, tolerance, inclusion, understanding and solidarity, in order to build a sustainable world of peace, solidarity and harmony; Whereas attaining peace involves the active and persistent process of persuading people of the benefits of peace, cooperation, tolerance, and nonviolence; Whereas peace is only attainable via a sustained co ...
#   'score': 0.75281425891182},
#  {'_id': ObjectId('63764ea6e6cbfc0792a0fea4'),
#   'bill_id': 'hjres41-117',
#   'bill_slug': 'hjres41',
#   'bill_type': 'hjres',
#   'number': 'H.J.RES.41',
#   'bill_uri': 'https://api.propublica.org/congress/v1/117/bills/hjres41.json',
#   'title': 'To establish a National Committee on Fiscal Responsibility and Reform.',
#   'short_title': 'National Committee on Fiscal Responsibility and Reform Act of 2021',
#   'sponsor_title': 'Rep.',
#   'sponsor_id': 'K000378',
#   'sponsor_name': 'Adam Kinzinger',
#   'sponsor_state': 'IL',
#   'sponsor_party': 'R',
#   'sponsor_uri': 'https://api.propublica.org/congress/v1/members/K000378.json',
#   'gpo_pdf_uri': None,
#   'congressdotgov_url': 'https://www.congress.gov/bill/117th-congress/house-joint-resolution/41',
#   'govtrack_url': 'https://www.govtrack.us/congress/bills/117/hjres41',
#   'introduced_date': '2021-04-16',
#   'active': False,
#   'last_vote': None,
#   'house_passage': None,
#   'senate_passage': None,
#   'enacted': None,
#   'vetoed': None,
#   'cosponsors': 1,
#   'cosponsors_by_party': {'D': 1},
#   'committees': 'House Rules Committee',
#   'committee_codes': ['HSRU'],
#   'subcommittee_codes': [],
#   'primary_subject': 'Economics and Public Finance',
#   'summary': 'National Committee on Fiscal Responsibility and Reform Act of 2021 This bill establishes the National Committee on Fiscal Responsibility and Reform to make recommendations to reduce the budget deficit by at least $3.25 trillion over FY2021-FY2031. The committee must be established as a joint select committee of Congress and consist of 12 Members of Congress appointed by specified members of the congressional leadership. The specific functions of the committee are to  investigate policies to improve the fiscal situation in the medium term; achieve fiscal sustainability over the long run;  propose legislation designed to balance the budget, excluding interest payments on the debt, by 2031; and  issue a final report to Congress.  Congress must use specified expedited legislative procedures to consider legislation that is approved by at least eight members of the committee.',
#   'summary_short': 'National Committee on Fiscal Responsibility and Reform Act of 2021 This bill establishes the National Committee on Fiscal Responsibility and Reform to make recommendations to reduce the budget deficit by at least $3.25 trillion over FY2021-FY2031. The committee must be established as a joint select committee of Congress and consist of 12 Members of Congress appointed by specified members of the congressional leadership. The specific functions of the committee are to  investigate policies to i...',
#   'latest_major_action_date': '2021-04-16',
#   'latest_major_action': 'Referred to the House Committee on Rules.',
#   'bill_text': "This joint resolution may be cited as the National Committee on Fiscal Responsibility and Reform Act of 2021. There is established a joint select committee of Congress to be known as the National Committee on Fiscal Responsibility and Reform (hereafter known as the Committee). The goal of the Committee shall be to reduce the deficit by at least $3,250,000,000,000 over the period of fiscal years 2021 to 2031. The functions of the Committee are to— investigate policies to improve the fiscal situation in the medium term; achieve fiscal sustainability over the long run; propose legislation designed to balance the budget, excluding interest payments on the debt, by 2031; and issue a final report to the appropriate congressional committees. The Committee shall be composed of 12 members appointed pursuant to subsection (b). Members of the Committee shall be appointed as follows: The majority leader of the Senate shall appoint three members from among Members of the Senate. The minority leader of the Senate shall appoint three members from among Members of the Senate. The Speaker of the House of Representatives shall appoint three members from among Members of the House of Representatives. The Speaker, in consultation with the minority leader, of the House of Representatives, shall appoint three members from among Members of the House of Representatives. There shall be four Co-Chairs of the Committee. The Co-Chairs shall be appointed not later than 14 calendar days after the date of enactment of this joint resolution. The Co-chairs shall be selected by: The majority leader of the Senate shall appoint one Co-Chair from among Members of the Senate. The minority leader of the Senate shall appoint one Co-Chair from among Members of the Senate. The Speaker of the House of Representatives shall appoint one Co-Chair from among Members of the House of Representatives. The minority leader of the House of Representatives shall appoint one Co-Chair from among Members of the House of Representatives. The Co-Chairs, acting jointly, shall hire the staff director of the Committee. Members of the Committee shall be appointed not later than 14 calendar days after the date of enactment of this joint resolution. Members shall be appointed for the life of the Committee. Any vacancy in the Committee shall not affect its powers, but shall be filled not later than 14 calendar days after the date on which the vacancy occurs, in the same manner as the original designation was made. If a member of the Committee ceases to be a Member of the House of Representatives or the Senate, as the case may be, the member is no longer a member of the Committee and a vacancy shall exist. No later than 360 days after the date of enactment of this joint resolution, the Committee shall vote on the approval of a final report containing a set of recommendations to achieve the mission set forth in this resolution. The issuance of a final report of the Committee shall require the approval of not less than 8 of the 12 members of the Committee. If the report and legislative language are approved by the Committee pursuant to subsection (b), the Committee shall submit the Committee report and legislative language described in section 3 to the President, the Vice President, the Speaker of the House of Representatives, and the majority and minority leaders of each House of Congress. Upon the approval or disapproval of the Committee report and legislative language pursuant to subsection (b), the Committee shall promptly make the full report and legislative language, and a record of the vote, available to the public. To enable the Committee to exercise its powers, functions, and duties, there are authorized to be disbursed by the Senate the actual and necessary expenses of the Committee approved by the co-chairs, subject to the rules and regulations of the Senate and the House. In carrying out its functions, the Committee is authorized to incur expenses in the same manner  ...
#   'score': 0.7510885341074021},
#  {'_id': ObjectId('63764e9ae6cbfc0792a0f9a0'),
#   'bill_id': 'hconres34-117',
#   'bill_slug': 'hconres34',
#   'bill_type': 'hconres',
#   'number': 'H.CON.RES.34',
#   'bill_uri': 'https://api.propublica.org/congress/v1/117/bills/hconres34.json',
#   'title': 'Expressing the sense of Congress that a carbon tax would be detrimental to the United States economy.',
#   'short_title': 'Expressing the sense of Congress that a carbon tax would be detrimental to the United States economy.',
#   'sponsor_title': 'Rep.',
#   'sponsor_id': 'S001176',
#   'sponsor_name': 'Steve Scalise',
#   'sponsor_state': 'LA',
#   'sponsor_party': 'R',
#   'sponsor_uri': 'https://api.propublica.org/congress/v1/members/S001176.json',
#   'gpo_pdf_uri': None,
#   'congressdotgov_url': 'https://www.congress.gov/bill/117th-congress/house-concurrent-resolution/34',
#   'govtrack_url': 'https://www.govtrack.us/congress/bills/117/hconres34',
#   'introduced_date': '2021-05-17',
#   'active': False,
#   'last_vote': None,
#   'house_passage': None,
#   'senate_passage': None,
#   'enacted': None,
#   'vetoed': None,
#   'cosponsors': 51,
#   'cosponsors_by_party': {'R': 51},
#   'committees': 'House Ways and Means Committee',
#   'committee_codes': ['HSWM'],
#   'subcommittee_codes': [],
#   'primary_subject': 'Taxation',
#   'summary': 'This concurrent resolution expresses the sense of Congress that a carbon tax would be detrimental to American families and businesses and is not in the best interest of the United States.',
#   'summary_short': 'This concurrent resolution expresses the sense of Congress that a carbon tax would be detrimental to American families and businesses and is not in the best interest of the United States.',
#   'latest_major_action_date': '2021-05-17',
#   'latest_major_action': 'Referred to the House Committee on Ways and Means.',
#   'bill_text': 'Whereas a carbon tax is a Federal tax on carbon released from fossil fuels; Whereas a carbon tax will increase energy prices, including the price of gasoline, electricity, natural gas, and home heating oil; Whereas a carbon tax will mean that families and consumers will pay more for essentials like food, gasoline, and electricity; Whereas a carbon tax will fall hardest on the poor, the elderly, and those on fixed incomes; Whereas a carbon tax will lead to more jobs and businesses moving overseas; Whereas a carbon tax will lead to less economic growth; Whereas American families will be harmed the most from a carbon tax; Whereas, according to the Energy Information Administration, the share of energy consumption during 2019 in the United States that was derived from fossil fuels was approximately 80 percent; Whereas a carbon tax will increase the cost of every good manufactured in the United States; Whereas a carbon tax will impose disproportionate burdens on certain industries, jobs, States, and geographic regions and would further restrict the global competitiveness of the United States; Whereas American ingenuity has led to innovations in energy exploration and development and has increased production of domestic energy resources on private and State-owned land which has created significant job growth and private capital investment; Whereas the energy policy of the United States should encourage continued private sector innovation and development and not increase the existing tax burden on manufacturers; Whereas the production of American energy resources increases the ability of the United States to maintain a competitive advantage in today’s global economy; Whereas a carbon tax would reduce America’s global competitiveness and would encourage development abroad in countries that do not impose this exorbitant tax burden; and Whereas the Congress and the President should focus on pro-growth solutions that encourage increased development of domestic resources: Now, therefore, be it That it is the sense of Congress that a carbon tax would be detrimental to American families and businesses, and is not in the best interest of the United States.',
#   'score': 0.5023041474654378},
#  {'_id': ObjectId('63764ee2e6cbfc0792a10d88'),
#   'bill_id': 's34-117',
#   'bill_slug': 's34',
#   'bill_type': 's',
#   'number': 'S.34',
#   'bill_uri': 'https://api.propublica.org/congress/v1/117/bills/s34.json',
#   'title': 'A bill to provide funding for cities, counties, and other units of general local government to prevent, prepare for, and respond to coronavirus.',
#   'short_title': 'Direct Support for Communities Act',
#   'sponsor_title': 'Sen.',
#   'sponsor_id': 'G000555',
#   'sponsor_name': 'Kirsten E. Gillibrand',
#   'sponsor_state': 'NY',
#   'sponsor_party': 'D',
#   'sponsor_uri': 'https://api.propublica.org/congress/v1/members/G000555.json',
#   'gpo_pdf_uri': None,
#   'congressdotgov_url': 'https://www.congress.gov/bill/117th-congress/senate-bill/34',
#   'govtrack_url': 'https://www.govtrack.us/congress/bills/117/s34',
#   'introduced_date': '2021-01-22',
#   'active': False,
#   'last_vote': None,
#   'house_passage': None,
#   'senate_passage': None,
#   'enacted': None,
#   'vetoed': None,
#   'cosponsors': 8,
#   'cosponsors_by_party': {'D': 8},
#   'committees': 'Senate Appropriations Committee',
#   'committee_codes': ['SSAP'],
#   'subcommittee_codes': [],
#   'primary_subject': 'Housing and Community Development',
#   'summary': 'Direct Support for Communities Act This bill provides FY2021 supplemental appropriations to the Department of Housing and Urban Development (HUD) to award additional Community Development Block Grants to units of local government and counties to prevent, prepare for, and respond to coronavirus and the COVID-19 (i.e., coronavirus disease 2019) public health emergency. Specifically, within 30 days, HUD must distribute 50% of such funds to metropolitan cities and other units of local government and 50% to counties and parishes. These funds may be used to cover costs or replace lost, delayed, or decreased revenues stemming from the COVID-19 public health emergency. Additionally, the bill designates the funding as emergency spending, which is exempt from discretionary spending limits.',
#   'summary_short': 'Direct Support for Communities Act This bill provides FY2021 supplemental appropriations to the Department of Housing and Urban Development (HUD) to award additional Community Development Block Grants to units of local government and counties to prevent, prepare for, and respond to coronavirus and the COVID-19 (i.e., coronavirus disease 2019) public health emergency. Specifically, within 30 days, HUD must distribute 50% of such funds to metropolitan cities and other units of local government ...',
#   'latest_major_action_date': '2021-01-22',
#   'latest_major_action': 'Read twice and referred to the Committee on Appropriations.',
#   'bill_text': 'Whereas a carbon tax is a Federal tax on carbon released from fossil fuels; Whereas a carbon tax will increase energy prices, including the price of gasoline, electricity, natural gas, and home heating oil; Whereas a carbon tax will mean that families and consumers will pay more for essentials like food, gasoline, and electricity; Whereas a carbon tax will fall hardest on the poor, the elderly, and those on fixed incomes; Whereas a carbon tax will lead to more jobs and businesses moving overseas; Whereas a carbon tax will lead to less economic growth; Whereas American families will be harmed the most from a carbon tax; Whereas, according to the Energy Information Administration, the share of energy consumption during 2019 in the United States that was derived from fossil fuels was approximately 80 percent; Whereas a carbon tax will increase the cost of every good manufactured in the United States; Whereas a carbon tax will impose disproportionate burdens on certain industries, jobs, States, and geographic regions and would further restrict the global competitiveness of the United States; Whereas American ingenuity has led to innovations in energy exploration and development and has increased production of domestic energy resources on private and State-owned land which has created significant job growth and private capital investment; Whereas the energy policy of the United States should encourage continued private sector innovation and development and not increase the existing tax burden on manufacturers; Whereas the production of American energy resources increases the ability of the United States to maintain a competitive advantage in today’s global economy; Whereas a carbon tax would reduce America’s global competitiveness and would encourage development abroad in countries that do not impose this exorbitant tax burden; and Whereas the Congress and the President should focus on pro-growth solutions that encourage increased development of domestic resources: Now, therefore, be it That it is the sense of Congress that a carbon tax would be detrimental to American families and businesses, and is not in the best interest of the United States.',
#   'score': 0.5023041474654378},
#  {'_id': ObjectId('63764e8de6cbfc0792a0f545'),
#   'bill_id': 'hconres38-117',
#   'bill_slug': 'hconres38',
#   'bill_type': 'hconres',
#   'number': 'H.CON.RES.38',
#   'bill_uri': 'https://api.propublica.org/congress/v1/117/bills/hconres38.json',
#   'title': 'Expressing support for the NATO alliance and increased alliance cooperation on opportunities and challenges.',
#   'short_title': 'Expressing support for the NATO alliance and increased alliance cooperation on opportunities and challenges.',
#   'sponsor_title': 'Rep.',
#   'sponsor_id': 'P000613',
#   'sponsor_name': 'Jimmy Panetta',
#   'sponsor_state': 'CA',
#   'sponsor_party': 'D',
#   'sponsor_uri': 'https://api.propublica.org/congress/v1/members/P000613.json',
#   'gpo_pdf_uri': None,
#   'congressdotgov_url': 'https://www.congress.gov/bill/117th-congress/house-concurrent-resolution/38',
#   'govtrack_url': 'https://www.govtrack.us/congress/bills/117/hconres38',
#   'introduced_date': '2021-06-14',
#   'active': False,
#   'last_vote': None,
#   'house_passage': None,
#   'senate_passage': None,
#   'enacted': None,
#   'vetoed': None,
#   'cosponsors': 9,
#   'cosponsors_by_party': {'D': 4, 'R': 5},
#   'committees': 'House Foreign Affairs Committee',
#   'committee_codes': ['HSFA'],
#   'subcommittee_codes': ['HSFA14'],
#   'primary_subject': 'International Affairs',
#   'summary': 'This resolution recognizes the contributions of international treaties and alliances to the national security of the United States and other alliance members. It also calls for robust U.S. leadership within NATO and continued U.S. engagement to assist NATO allies in meeting their burden-sharing targets.',
#   'summary_short': 'This resolution recognizes the contributions of international treaties and alliances to the national security of the United States and other alliance members. It also calls for robust U.S. leadership within NATO and continued U.S. engagement to assist NATO allies in meeting their burden-sharing targets.',
#   'latest_major_action_date': '2021-08-04',
#   'latest_major_action': 'Referred to the Subcommittee on Europe, Energy, the Environment and Cyber.',
#   'bill_text': 'Whereas the North Atlantic Treaty Organization (NATO) came into being through the North Atlantic Treaty, which entered into force on April 4, 1949, between the United States of America and the other founding members of the North Atlantic Treaty Organization, and has served as a pillar of international peace and stability, a critical component of United States security, and a deterrent against adversaries and external threats; Whereas Congress has repeatedly supported and affirmed that— NATO is one of the most successful military alliances in history, deterring the outbreak of another world war, protecting the territorial integrity of its members, and seeing the Cold War through to a peaceful conclusion; NATO remains the foundation of United States foreign policy to promote a Europe that is whole, free, and at peace; the United States is solemnly committed to the North Atlantic Treaty Organization’s principle of collective defense as enumerated in Article 5 of the North Atlantic Treaty; and each alliance member ought to honor the decision at the NATO Wales Summit in 2014 to spend at least 2 percent of that country’s gross domestic product on defense by 2024; Whereas it is the policy of the United States— to remain a member in good standing of NATO; to continue to work with NATO members to meet their 2014 Wales Defense Investment Pledge commitments; and to support robust United States funding for the European Deterrence Initiative, which increases the ability of the United States and its allies to deter and defend against aggression; Whereas the United States should take every action to reinforce its global reputation as a country that fully complies with its obligations under the international treaties to which it is a party; and Whereas NATO was founded on the principles of democracy, individual liberty, and the rule of law: Now, therefore, be it That Congress— recognizes the contributions to the national security of the United States and other alliance members derived from international treaties and alliances; supports the President’s reaffirmation of the United States commitment to Article 5 and to NATO collective defense based on shared democratic values;  calls for— robust United States leadership within NATO; coordination with steadfast allies and partners on shared peace and security concerns; and continued United States engagement to assist NATO allies in meeting their burden-sharing targets; supports increased cooperation on new and persistent threats to democratic institutions from Russia and other competitors, as well as to critical global challenges like climate change and the COVID–19 pandemic; and supports increased cooperation and dialogue relating to how the alliance may modernize, pursue new opportunities, and address potential internal threats to democracy.',
#   'score': 0.5018796992481203},
#  {'_id': ObjectId('63764edfe6cbfc0792a10d43'),
#   'bill_id': 's38-117',
#   'bill_slug': 's38',
#   'bill_type': 's',
#   'number': 'S.38',
#   'bill_uri': 'https://api.propublica.org/congress/v1/117/bills/s38.json',
#   'title': 'A bill to specify the Federal share of the costs of certain duty of the National Guard in connection with the Coronavirus Disease 2019.',
#   'short_title': 'A bill to specify the Federal share of the costs of certain duty of the National Guard in connection with the Coronavirus Disease 2019.',
#   'sponsor_title': 'Sen.',
#   'sponsor_id': 'L000174',
#   'sponsor_name': 'Patrick J. Leahy',
#   'sponsor_state': 'VT',
#   'sponsor_party': 'D',
#   'sponsor_uri': 'https://api.propublica.org/congress/v1/members/L000174.json',
#   'gpo_pdf_uri': None,
#   'congressdotgov_url': 'https://www.congress.gov/bill/117th-congress/senate-bill/38',
#   'govtrack_url': 'https://www.govtrack.us/congress/bills/117/s38',
#   'introduced_date': '2021-01-25',
#   'active': False,
#   'last_vote': None,
#   'house_passage': None,
#   'senate_passage': None,
#   'enacted': None,
#   'vetoed': None,
#   'cosponsors': 12,
#   'cosponsors_by_party': {'D': 11, 'ID': 1},
#   'committees': 'Senate Armed Services Committee',
#   'committee_codes': ['SSAS'],
#   'subcommittee_codes': [],
#   'primary_subject': 'Armed Forces and National Security',
#   'summary': 'This bill requires the federal government to pay states for 100% of the cost of National Guard duty for a mission assignment validated by the Federal Emergency Management Agency pursuant to certain declarations related to the COVID-19 (i.e., coronavirus disease 2019) public health emergency. The bill applies to declarations, with respect to COVID-19, of major disasters, emergencies, national emergencies, and public health emergencies.',
# ...
#   'score': 0.500615763546798},
#  {'_id': ObjectId('63764ee3e6cbfc0792a10d93'),
#   'bill_id': 's24-117',
#   'bill_slug': 's24',
#   'bill_type': 's',
#   'number': 'S.24',
#   'bill_uri': 'https://api.propublica.org/congress/v1/117/bills/s24.json',
#   'title': 'A bill to protect the personal health data of all Americans.',
#   'short_title': 'Protecting Personal Health Data Act',
#   'sponsor_title': 'Sen.',
#   'sponsor_id': 'K000367',
#   'sponsor_name': 'Amy Klobuchar',
#   'sponsor_state': 'MN',
#   'sponsor_party': 'D',
#   'sponsor_uri': 'https://api.propublica.org/congress/v1/members/K000367.json',
#   'gpo_pdf_uri': None,
#   'congressdotgov_url': 'https://www.congress.gov/bill/117th-congress/senate-bill/24',
#   'govtrack_url': 'https://www.govtrack.us/congress/bills/117/s24',
#   'introduced_date': '2021-01-22',
#   'active': False,
#   'last_vote': None,
#   'house_passage': None,
#   'senate_passage': None,
#   'enacted': None,
#   'vetoed': None,
#   'cosponsors': 2,
#   'cosponsors_by_party': {'R': 1, 'D': 1},
#   'committees': 'Senate Health, Education, Labor, and Pensions Committee',
#   'committee_codes': ['SSHR'],
#   'subcommittee_codes': [],
#   'primary_subject': 'Health',
#   'summary': 'Protecting Personal Health Data Act This bill directs the Department of Health and Human Services to regulate consumer devices, services, applications, and software that (1) are primarily designed for or marketed to consumers; (2) primarily collect or use personal health data; and (3) are not primarily designed for use by\xa0entities such as health care plans, providers,\xa0or clearinghouses. The bill also establishes a national task force on health data protection.',
#   'summary_short': 'Protecting Personal Health Data Act This bill directs the Department of Health and Human Services to regulate consumer devices, services, applications, and software that (1) are primarily designed for or marketed to consumers; (2) primarily collect or use personal health data; and (3) are not primarily designed for use by\xa0entities such as health care plans, providers,\xa0or clearinghouses. The bill also establishes a national task force on health data protection.',
#   'latest_major_action_date': '2021-01-22',
#   'latest_major_action': 'Read twice and referred to the Committee on Health, Education, Labor, and Pensions.',
#   'bill_text': 'Whereas section 6(d) of the Fair Labor Standards Act of 1938 (29 U.S.C. 206(d)(1)) prohibits discrimination in compensation for equal work on the basis of sex; Whereas title VII of the Civil Rights Act of 1964 (42 U.S.C. 2000e et seq.) prohibits discrimination in compensation because of race, color, religion, national origin, or sex; Whereas over 5 decades after the passage of the Equal Pay Act of 1963 (29 U.S.C. 206 note), Census Bureau data show that women working full-time, year-round are paid an average of 82 cents for every dollar paid to men, while Asian-American women working full-time, year-round are paid 87 cents, White, non-Hispanic women working full-time, year-round are paid 79 cents, African-American women working full-time, year-round are paid 63 cents, Native Hawaiian and Pacific Islander women working full-time, year-round are paid 60 cents, American Indian and Alaska Native women working full-time, year-round are paid 60 cents, and Latinas working full-time, year-round are paid 55 cents for every dollar paid to White, non-Hispanic men; Whereas March 24, 2021, is Equal Pay Day, marking the day that symbolizes how long into 2021 women must work to make what men were paid in 2020; Whereas March 9, 2021, is Asian American and Pacific Islander Women’s Equal Pay Day; August 3, 2021, is Black Women’s Equal Pay Day; September 8, 2021, is Native Women’s Equal Pay Day; and October 21, 2021, is Latinas’ Equal Pay Day; Whereas if current trends continue, Asian women are projected to close the gender pay gap in 22 years, White women in 50 years, Black women in 350 years, and Latinas in 432 years; Whereas the disparity in median annual earnings for women and men working full-time, year-round is $10,157; which can add up to more than $400,000 over a career; Whereas women’s median earnings are less than men’s at every level of academic achievement, with women with less than a high school diploma earning 72 percent of men’s earnings, and women with a professional degree earning 68 percent of men’s earnings at the same level of education; Whereas women are often paid less than men with lower levels of education, with women with associate’s degrees paid less than men with a high school diploma, and women with master’s degrees paid less than men with bachelor’s degrees; Whereas in the United States, mothers are breadwinners in nearly half of families with children under 18, and mothers working full-time typically are paid 75 percent of what fathers are paid; Whereas the gender wage gap collectively costs women employed full-time in the United States more than $956 billion in annual lost wages, so that families have less money to spend on goods and services that help drive economic growth; Whereas if the annual gender wage gap were eliminated, on average, a working woman in the United States would have enough money for approximately 13 more months of childcare, 9 additional months of rent, 6 additional months of mortgage and utilities payments, the full cost of tuition and fees for attending a 2-year college, almost 7 additional months of premiums for employer-based health insurance, more than 8 additional years of birth control, more than 64 weeks of food, or enough money to pay off student loan debt in just under 3 years; Whereas women hold two-thirds of the Nation’s $1.54 trillion in outstanding student loan debt, totaling over $929 billion, and are less likely to be able to pay off their student loan debt promptly due to wage disparities; Whereas the wage gap impacts women’s ability to save for retirement and women’s total Social Security and pension benefits, and older women are more likely than men to live in poverty; Whereas sex discrimination in education, hiring, and promotion has played a role in maintaining a workforce segregated by sex; Whereas sex-based wage differentials— depress employee wages and living standards necessary for health and well-being; reduce family incomes and contribute to the higher ...
#   'score': 0.5005988023952096},
#  {'_id': ObjectId('63764eade6cbfc0792a101d7'),
#   'bill_id': 'hconres24-117',
#   'bill_slug': 'hconres24',
#   'bill_type': 'hconres',
#   'number': 'H.CON.RES.24',
#   'bill_uri': 'https://api.propublica.org/congress/v1/117/bills/hconres24.json',
#   'title': 'Recognizing the significance of equal pay and the disparity between wages paid to men and women.',
#   'short_title': 'Recognizing the significance of equal pay and the disparity between wages paid to men and women.',
#   'sponsor_title': 'Rep.',
#   'sponsor_id': 'F000462',
#   'sponsor_name': 'Lois Frankel',
#   'sponsor_state': 'FL',
#   'sponsor_party': 'D',
#   'sponsor_uri': 'https://api.propublica.org/congress/v1/members/F000462.json',
#   'gpo_pdf_uri': None,
#   'congressdotgov_url': 'https://www.congress.gov/bill/117th-congress/house-concurrent-resolution/24',
#   'govtrack_url': 'https://www.govtrack.us/congress/bills/117/hconres24',
#   'introduced_date': '2021-03-23',
#   'active': False,
#   'last_vote': None,
#   'house_passage': None,
#   'senate_passage': None,
#   'enacted': None,
#   'vetoed': None,
#   'cosponsors': 138,
#   'cosponsors_by_party': {'D': 138},
#   'committees': 'House Education and Labor Committee',
#   'committee_codes': ['HSED'],
#   'subcommittee_codes': [],
#   'primary_subject': 'Labor and Employment',
#   'summary': "This resolution recognizes the disparity between wages paid to men and women, and its impact on women, families, and the nation and reaffirms Congress' commitment to supporting equal pay and to narrowing the gender wage gap.    ",
#   'summary_short': 'This resolution recognizes the disparity between wages paid to men and women, and its impact on women, families, and the nation and reaffirms Congress&#39; commitment to supporting equal pay and to narrowing the gender wage gap.    ',
#   'latest_major_action_date': '2021-03-23',
#   'latest_major_action': 'Referred to the House Committee on Education and Labor.',
#   'bill_text': 'Whereas section 6(d) of the Fair Labor Standards Act of 1938 (29 U.S.C. 206(d)(1)) prohibits discrimination in compensation for equal work on the basis of sex; Whereas title VII of the Civil Rights Act of 1964 (42 U.S.C. 2000e et seq.) prohibits discrimination in compensation because of race, color, religion, national origin, or sex; Whereas over 5 decades after the passage of the Equal Pay Act of 1963 (29 U.S.C. 206 note), Census Bureau data show that women working full-time, year-round are paid an average of 82 cents for every dollar paid to men, while Asian-American women working full-time, year-round are paid 87 cents, White, non-Hispanic women working full-time, year-round are paid 79 cents, African-American women working full-time, year-round are paid 63 cents, Native Hawaiian and Pacific Islander women working full-time, year-round are paid 60 cents, American Indian and Alaska Native women working full-time, year-round are paid 60 cents, and Latinas working full-time, year-round are paid 55 cents for every dollar paid to White, non-Hispanic men; Whereas March 24, 2021, is Equal Pay Day, marking the day that symbolizes how long into 2021 women must work to make what men were paid in 2020; Whereas March 9, 2021, is Asian American and Pacific Islander Women’s Equal Pay Day; August 3, 2021, is Black Women’s Equal Pay Day; September 8, 2021, is Native Women’s Equal Pay Day; and October 21, 2021, is Latinas’ Equal Pay Day; Whereas if current trends continue, Asian women are projected to close the gender pay gap in 22 years, White women in 50 years, Black women in 350 years, and Latinas in 432 years; Whereas the disparity in median annual earnings for women and men working full-time, year-round is $10,157; which can add up to more than $400,000 over a career; Whereas women’s median earnings are less than men’s at every level of academic achievement, with women with less than a high school diploma earning 72 percent of men’s earnings, and women with a professional degree earning 68 percent of men’s earnings at the same level of education; Whereas women are often paid less than men with lower levels of education, with women with associate’s degrees paid less than men with a high school diploma, and women with master’s degrees paid less than men with bachelor’s degrees; Whereas in the United States, mothers are breadwinners in nearly half of families with children under 18, and mothers working full-time typically are paid 75 percent of what fathers are paid; Whereas the gender wage gap collectively costs women employed full-time in the United States more than $956 billion in annual lost wages, so that families have less money to spend on goods and services that help drive economic growth; Whereas if the annual gender wage gap were eliminated, on average, a working woman in the United States would have enough money for approximately 13 more months of childcare, 9 additional months of rent, 6 additional months of mortgage and utilities payments, the full cost of tuition and fees for attending a 2-year college, almost 7 additional months of premiums for employer-based health insurance, more than 8 additional years of birth control, more than 64 weeks of food, or enough money to pay off student loan debt in just under 3 years; Whereas women hold two-thirds of the Nation’s $1.54 trillion in outstanding student loan debt, totaling over $929 billion, and are less likely to be able to pay off their student loan debt promptly due to wage disparities; Whereas the wage gap impacts women’s ability to save for retirement and women’s total Social Security and pension benefits, and older women are more likely than men to live in poverty; Whereas sex discrimination in education, hiring, and promotion has played a role in maintaining a workforce segregated by sex; Whereas sex-based wage differentials— depress employee wages and living standards necessary for health and well-being; reduce family incomes and contribute to the higher ...
#   'score': 0.5005988023952096}]
