# %%
import pandas as pd
import numpy as np
import requests
import json
import os

# %%
url = 'https://raw.githubusercontent.com/jkropko/contrans/main/examples/ASA%20All%20NBA%20Raw%20Data.csv'
nba = pd.read_csv(url)
nba
# Out:
#             game_id   game_date  OT H_A Team_Abbrev  Team_Score  Team_pace  \
# 0      202204100BRK  2022-04-10   0   A         IND         126      103.9
# 1      202204100BRK  2022-04-10   0   A         IND         126      103.9
# 2      202204100BRK  2022-04-10   0   A         IND         126      103.9
# 3      202204100BRK  2022-04-10   0   A         IND         126      103.9
# 4      202204100BRK  2022-04-10   0   A         IND         126      103.9
# ...             ...         ...  ..  ..         ...         ...        ...
# 31603  202201130NOP  2022-01-13   0   A         LAC          89       97.0
# 31604  202201150SAS  2022-01-15   0   A         LAC          94       92.7
# 31605  202112220SAC  2021-12-22   0   A         LAC         105       95.5
# 31606  202112260LAC  2021-12-26   0   H         LAC         100       99.8
# 31607  202112270LAC  2021-12-27   0   H         LAC         108       99.5
#
# ...

# %% [markdown]
# ## Second Normal Form
# Every non-prime column must depend on the ENTIRE primary key (gameid + playerid) and not just part of the primary key (not just the playerid or gameid)

# %%
nba['game_player_id']=nba['game_id']+nba['player_id']

# %%
nba.head(3).T

# %% [markdown]
# ## Third Normal Form
# Need all of the dependecies of a second normal form
#
# Calculated column:
# -fg_pct
# -fg
# -fg3_pct
# We'll delete these
#
# Transitive Dependencies:
# -some columns depend depend on player
# -some columns depend on game
# -some columns depend on team
# Each of these will get a seperate table!
